# %%
import random
import os

import pandas as pd
import boto3
from faker import Faker


faker = Faker()

# %% [markdown]
# ## GENERATE SAMPLE DATA

# %%
df = pd.DataFrame([
    {
        'price': round(1000 * random.random(), 2),
        'name': faker.name(),
        'email': faker.email(),
        'quantity': random.randint(1, 10),
    }
    for i in range(0, 10 ** 3)
])
df.head(5)
# Out:
#                             email                    name   price  quantity
# 0          lurenadare@hotmail.com  Dr. Frankie Jacobi DDS  946.72         7
# 1             murphyines@hand.com          Rafael Corkery  225.38        10
# 2  rutherfordjohnston@hotmail.com       Mr. Connor Casper  600.93         8
# 3   jerroldbalistreri@collier.biz          Paulo Lindgren  950.96         2
# 4     schaeferrozella@hotmail.com              Tal Raynor   72.22         9

# %%
df.to_csv('./shopping_1.csv', index=False)

# %% [markdown]
# ## ATHENA create tables

# %%
# CREATE EXTERNAL TABLE IF NOT EXISTS lakey.shopping (
#   `email` string,
#   `name` string,
#   `price` float,
#   `quantity` int 
# )
# ROW FORMAT SERDE 'org.apache.hadoop.hive.serde2.lazy.LazySimpleSerDe'
# WITH SERDEPROPERTIES (
#   'serialization.format' = ',',
#   'field.delim' = ','
# ) LOCATION 's3://lakey/tables/shopping/'
# TBLPROPERTIES ('has_encrypted_data'='false');

# %% [markdown]
# ## Connect with ATHENA and Query

# %%
athena = boto3.client(
    'athena',
    region_name=os.environ['AWS_LAKEY_REGION'],
    aws_access_key_id=os.environ['AWS_S3_KEY_ID'],
    aws_secret_access_key=os.environ['AWS_S3_KEY_SECRET'])

# %%
s3 = boto3.client(
    's3',
    region_name=os.environ['AWS_LAKEY_REGION'],
    aws_access_key_id=os.environ['AWS_S3_KEY_ID'],
    aws_secret_access_key=os.environ['AWS_S3_KEY_SECRET'])

# %%
response = athena.start_query_execution(
    QueryString='SELECT * FROM shopping where quantity > 3;',
    QueryExecutionContext={
      'Database': 'lakey'
    },
    ResultConfiguration={
      'OutputLocation': 's3://lakey/results/',
    })

# %%
response
# Out:
# {'QueryExecutionId': 'cd471422-ef8f-484f-801a-2c7f52f47d3b',
#  'ResponseMetadata': {'RequestId': 'e3fc6ba8-fa82-4964-b6f7-2637b5fe0174',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#    'date': 'Thu, 25 Apr 2019 20:14:55 GMT',
#    'x-amzn-requestid': 'e3fc6ba8-fa82-4964-b6f7-2637b5fe0174',
#    'content-length': '59',
#    'connection': 'keep-alive'},
#   'RetryAttempts': 0}}

# %%
s3.download_file('lakey', 'results/cd471422-ef8f-484f-801a-2c7f52f47d3b.csv', './results.csv')
# response['QueryExecutionId']

# %%
s3.put_object(
    Key='/results/dc5f60c4-881d-4390-89b2-555cd9999e27.csv',
    Bucket='lakey',
    ACL='public-read')
# Out:
# {'ResponseMetadata': {'RequestId': '87A9C9A2DBDFC4A1',
#   'HostId': 'E74VKux7dTPx4m1YMyhK3PTpAWMraV7mgKUlIRl7mw7dnnf1zxaJ17AgzFZQdRVs/sJJwWhsZZE=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'E74VKux7dTPx4m1YMyhK3PTpAWMraV7mgKUlIRl7mw7dnnf1zxaJ17AgzFZQdRVs/sJJwWhsZZE=',
#    'x-amz-request-id': '87A9C9A2DBDFC4A1',
#    'date': 'Fri, 26 Apr 2019 09:44:25 GMT',
#    'etag': '"d41d8cd98f00b204e9800998ecf8427e"',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'ETag': '"d41d8cd98f00b204e9800998ecf8427e"'}

# %%
s3.get_object_acl(
    Key='/results/dc5f60c4-881d-4390-89b2-555cd9999e27.csv',
    Bucket='lakey')
# Out:
# {'ResponseMetadata': {'RequestId': '680CFD4A6793DFE0',
#   'HostId': 'Fd39564EkHL6kwhs9fKZU3tbFkwmoGt9KaNWBV1nDxvEVrPRIpx90nD1gLCulHnI++czSCSAgxU=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'Fd39564EkHL6kwhs9fKZU3tbFkwmoGt9KaNWBV1nDxvEVrPRIpx90nD1gLCulHnI++czSCSAgxU=',
#    'x-amz-request-id': '680CFD4A6793DFE0',
#    'date': 'Fri, 26 Apr 2019 09:39:45 GMT',
#    'content-type': 'application/xml',
#    'transfer-encoding': 'chunked',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'Owner': {'ID': '3f574f8158d7a806f65506cd2d420f9f1f411f5dd67a6d444c09a8ad624125f0'},
#  'Grants': [{'Grantee': {'ID': '3f574f8158d7a806f65506cd2d420f9f1f411f5dd67a6d444c09a8ad624125f0',
#     'Type': 'CanonicalUser'},
#    'Permission': 'FULL_CONTROL'},
#   {'Grantee': {'Type': 'Group',
#     'URI': 'http://acs.amazonaws.com/groups/global/AllUsers'},
#    'Permission': 'READ'}]}

# %%
{'ResponseMetadata': {'RequestId': 'BE5EF245147D9544',
  'HostId': 'Xx/trl9/shIYM2B3RJfhbT9mD6Io12i0tb3bHWZWVIz96w4ktS9Y0ATVzQMnoi2R1kMDRxK9bZc=',
  'HTTPStatusCode': 200,
  'HTTPHeaders': {'x-amz-id-2': 'Xx/trl9/shIYM2B3RJfhbT9mD6Io12i0tb3bHWZWVIz96w4ktS9Y0ATVzQMnoi2R1kMDRxK9bZc=',
   'x-amz-request-id': 'BE5EF245147D9544',
   'date': 'Fri, 26 Apr 2019 09:29:46 GMT',
   'content-type': 'application/xml',
   'transfer-encoding': 'chunked',
   'server': 'AmazonS3'},
  'RetryAttempts': 0},
 'Owner': {'ID': '3f574f8158d7a806f65506cd2d420f9f1f411f5dd67a6d444c09a8ad624125f0'},
 'Grants': [{'Grantee': {'ID': '3f574f8158d7a806f65506cd2d420f9f1f411f5dd67a6d444c09a8ad624125f0',
    'Type': 'CanonicalUser'},
   'Permission': 'FULL_CONTROL'},
  {'Grantee': {'Type': 'Group',
    'URI': 'http://acs.amazonaws.com/groups/global/AllUsers'},
   'Permission': 'READ'}]}

# %% [markdown]
# ## SAMPLING

# %%
df.to_dict(orient='records')
# Out:
# [{'email': 'lurenadare@hotmail.com',
#   'name': 'Dr. Frankie Jacobi DDS',
#   'price': 946.72,
#   'quantity': 7},
#  {'email': 'murphyines@hand.com',
#   'name': 'Rafael Corkery',
#   'price': 225.38,
#   'quantity': 10},
#  {'email': 'rutherfordjohnston@hotmail.com',
#   'name': 'Mr. Connor Casper',
#   'price': 600.93,
#   'quantity': 8},
#  {'email': 'jerroldbalistreri@collier.biz',
#   'name': 'Paulo Lindgren',
#   'price': 950.96,
#   'quantity': 2},
#  {'email': 'schaeferrozella@hotmail.com',
#   'name': 'Tal Raynor',
#   'price': 72.22,
#   'quantity': 9},
#  {'email': 'ratkemadelene@bins-eichmann.info',
#   'name': 'Alexander Gibson',
#   'price': 331.08,
#   'quantity': 5},
#  {'email': 'genesis38@gmail.com',
#   'name': 'Lark Nikolaus I',
#   'price': 326.37,
#   'quantity': 8},
#  {'email': 'kimberly19@ferry.com',
#   'name': 'Stan King',
#   'price': 574.34,
#   'quantity': 4},
#  {'email': 'lolitakunze@brekke.com',
#   'name': 'Dr. Dannie Gerlach',
#   'price': 716.59,
#   'quantity': 2},
#  {'email': 'prentice59@lehner.info',
#   'name': 'Miss Stella Herman',
#   'price': 591.5,
#   'quantity': 6},
#  {'email': 'aschulist@beer-gottlieb.org',
#   'name': 'Cherryl Schinner',
#   'price': 702.17,
#   'quantity': 5},
#  {'email': 'pferry@yahoo.com',
#   'name': 'Elfie Lesch',
#   'price': 777.33,
#   'quantity': 3},
#  {'email': 'labadienorene@yahoo.com',
#   'name': 'Sherman Lesch',
#   'price': 796.25,
#   'quantity': 4},
#  {'email': 'fkutch@gmail.com',
#   'name': 'Mr. Robin Spinka Sr.',
#   'price': 15.31,
#   'quantity': 8},
#  {'email': 'bergnaumlyndsey@yahoo.com',
#   'name': 'Vashti Mertz',
#   'price': 2.66,
#   'quantity': 8},
#  {'email': 'antoinette06@farrell-harvey.com',
#   'name': 'Nedra Reinger',
#   'price': 59.64,
#   'quantity': 5},
#  {'email': 'ricci72@gmail.com',
#   'name': 'Tavion Brekke',
#   'price': 999.82,
#   'quantity': 2},
#  {'email': 'schowaltereura@franecki-dooley.com',
#   'name': 'Jaleel Weber',
#   'price': 280.46,
#   'quantity': 4},
#  {'email': 'zokon@marvin.com',
#   'name': 'Chandler Orn',
#   'price': 133.29,
#   'quantity': 6},
#  {'email': 'nabshire@collier.info',
#   'name': 'Yaritza Stokes',
#   'price': 640.88,
#   'quantity': 10},
#  {'email': 'lavernarau@yahoo.com',
#   'name': 'Clark Lubowitz Sr.',
#   'price': 661.53,
#   'quantity': 10},
#  {'email': 'collette74@yahoo.com',
#   'name': 'Patrick Beer',
#   'price': 623.86,
#   'quantity': 2},
#  {'email': 'orunolfsdottir@kutch.com',
#   'name': 'Mr. Talmage Swaniawski',
#   'price': 59.92,
#   'quantity': 2},
#  {'email': 'nhaag@hotmail.com',
#   'name': 'Mr. Winton Hyatt',
#   'price': 381.4,
#   'quantity': 10},
#  {'email': 'kamyalind@shields.com',
#   'name': 'Brianne Muller',
#   'price': 542.77,
#   'quantity': 7},
#  {'email': 'clarkfarrell@gmail.com',
#   'name': 'Mintie Kirlin',
#   'price': 845.98,
#   'quantity': 7},
#  {'email': 'julie05@conroy.com',
#   'name': 'Dr. Masao Swift',
#   'price': 874.43,
#   'quantity': 3},
#  {'email': 'raymundo39@thompson.com',
#   'name': 'Unnamed Dickens',
#   'price': 224.46,
#   'quantity': 4},
#  {'email': 'migdaliapouros@upton.net',
#   'name': 'Dr. Anabelle Lemke PhD',
#   'price': 364.61,
#   'quantity': 5},
#  {'email': 'schustershelby@gmail.com',
#   'name': 'Dr. Clare Stiedemann',
#   'price': 240.97,
#   'quantity': 3},
#  {'email': 'schulistalyse@hotmail.com',
#   'name': 'Ms. Adria Gleichner MD',
#   'price': 580.09,
#   'quantity': 1},
#  {'email': 'ozemlak@considine.net',
#   'name': 'Mrs. Kristy Braun',
#   'price': 668.21,
#   'quantity': 2},
#  {'email': 'friesenburton@hotmail.com',
#   'name': 'Colonel McCullough',
#   'price': 15.61,
#   'quantity': 4},
#  {'email': 'pferry@gmail.com',
#   'name': 'Casimiro Cremin',
#   'price': 783.0,
#   'quantity': 8},
#  {'email': 'zenas01@casper.com',
#   'name': 'Adonis Daugherty',
#   'price': 188.46,
#   'quantity': 10},
#  {'email': 'greichel@deckow.com',
#   'name': 'Williemae Jaskolski',
#   'price': 967.93,
#   'quantity': 9},
#  {'email': 'spadberg@gmail.com',
#   'name': 'Meagan Zemlak MD',
#   'price': 95.77,
#   'quantity': 3},
#  {'email': 'elaynehagenes@yahoo.com',
#   'name': 'Mr. Ezra Gorczany',
#   'price': 626.23,
#   'quantity': 2},
#  {'email': 'watersberneice@hotmail.com',
#   'name': 'Mintie Champlin',
#   'price': 218.73,
#   'quantity': 5},
#  {'email': 'shelby45@gmail.com',
#   'name': 'Norris Towne III',
#   'price': 931.89,
#   'quantity': 8},
#  {'email': 'romelloruecker@hotmail.com',
#   'name': 'Cris Paucek',
#   'price': 825.18,
#   'quantity': 1},
#  {'email': 'jaltenwerth@medhurst.net',
#   'name': 'Mr. Matias Streich Jr.',
#   'price': 8.52,
#   'quantity': 5},
#  {'email': 'vonshelba@kertzmann-hills.com',
#   'name': 'Arietta Halvorson',
#   'price': 975.62,
#   'quantity': 2},
#  {'email': 'raekwon30@emard.biz',
#   'name': 'Tinnie Goodwin',
#   'price': 462.7,
#   'quantity': 5},
#  {'email': 'yahaira33@funk.com',
#   'name': 'Diamond Orn PhD',
#   'price': 277.25,
#   'quantity': 9},
#  {'email': 'hopperollie@schaden-fay.info',
#   'name': 'Rhea Bogan',
#   'price': 619.43,
#   'quantity': 8},
#  {'email': 'shanita82@yahoo.com',
#   'name': 'Alexande Grady DVM',
#   'price': 896.4,
#   'quantity': 2},
#  {'email': 'hilpertgaylene@wunsch.info',
#   'name': 'Pearla Braun',
#   'price': 203.86,
#   'quantity': 6},
#  {'email': 'dickinsonashlyn@kessler.org',
#   'name': 'Averi Brown',
#   'price': 207.09,
#   'quantity': 1},
#  {'email': 'uhilpert@mertz.com',
#   'name': 'Noel Reynolds',
#   'price': 360.03,
#   'quantity': 9},
#  {'email': 'sylvaniarolfson@powlowski.com',
#   'name': 'Eli Wehner',
#   'price': 613.2,
#   'quantity': 8},
#  {'email': 'dcarter@bernier-hahn.net',
#   'name': 'Ermina Reichel',
#   'price': 405.6,
#   'quantity': 9},
#  {'email': 'torpclint@schoen-west.com',
#   'name': 'Annmarie Lakin DDS',
#   'price': 830.63,
#   'quantity': 8},
#  {'email': 'gerholddelilah@hotmail.com',
#   'name': 'Dr. Demarco Ferry DVM',
#   'price': 56.86,
#   'quantity': 7},
#  {'email': 'gleichnereithel@gmail.com',
#   'name': 'Dr. Teri Hermann',
#   'price': 749.09,
#   'quantity': 7},
#  {'email': 'autumn66@gmail.com',
#   'name': 'Dr. Christa Kohler',
#   'price': 632.3,
#   'quantity': 6},
#  {'email': 'omoen@gottlieb.com',
#   'name': 'Matilde Schaden',
#   'price': 497.71,
#   'quantity': 5},
#  {'email': 'norahwolff@hotmail.com',
#   'name': 'Tamica Glover DVM',
#   'price': 668.83,
#   'quantity': 8},
#  {'email': 'gidget96@hotmail.com',
#   'name': 'Leila Kessler',
#   'price': 351.04,
#   'quantity': 3},
#  {'email': 'michalegreen@gmail.com',
#   'name': 'Sabra Schumm',
#   'price': 738.81,
#   'quantity': 3},
#  {'email': 'tlynch@hotmail.com',
#   'name': 'Connor Roberts',
#   'price': 422.48,
#   'quantity': 7},
#  {'email': 'tremblaykolby@yahoo.com',
#   'name': 'Miss Alexina Yost',
#   'price': 386.48,
#   'quantity': 7},
#  {'email': 'gurney52@hotmail.com',
#   'name': 'Markel Pfeffer',
#   'price': 648.57,
#   'quantity': 7},
#  {'email': 'javion91@king-greenfelder.com',
#   'name': 'Emanuel Lynch',
#   'price': 478.78,
#   'quantity': 8},
#  {'email': 'qkovacek@little-cormier.com',
#   'name': 'Dr. Christoper McDermott',
#   'price': 532.78,
#   'quantity': 4},
#  {'email': 'jfriesen@yahoo.com',
#   'name': 'Marinda Bailey',
#   'price': 570.31,
#   'quantity': 10},
#  {'email': 'cami27@hotmail.com',
#   'name': 'Kaylyn Hahn',
#   'price': 848.64,
#   'quantity': 2},
#  {'email': 'zgrady@gmail.com',
#   'name': 'Ricki Hayes',
#   'price': 436.68,
#   'quantity': 3},
#  {'email': 'rauolinda@hansen.com',
#   'name': 'Colette Brekke',
#   'price': 551.85,
#   'quantity': 1},
#  {'email': 'philmohr@howe.biz',
#   'name': 'Tarah Schiller DDS',
#   'price': 424.53,
#   'quantity': 9},
#  {'email': 'ekohler@raynor.com',
#   'name': 'Toma Greenfelder',
#   'price': 654.81,
#   'quantity': 10},
#  {'email': 'estel58@bailey.org',
#   'name': 'Shelbi Hackett',
#   'price': 208.52,
#   'quantity': 5},
#  {'email': 'coltenkulas@wintheiser.com',
#   'name': 'Theron Mosciski I',
#   'price': 213.79,
#   'quantity': 4},
#  {'email': 'hodkiewiczdenis@white.biz',
#   'name': 'Jensen Greenholt IV',
#   'price': 403.73,
#   'quantity': 8},
#  {'email': 'bashiriantatsuo@kovacek.com',
#   'name': 'Lucio Gorczany',
#   'price': 512.37,
#   'quantity': 5},
#  {'email': 'anthoney39@yahoo.com',
#   'name': 'Vela Treutel DVM',
#   'price': 606.7,
#   'quantity': 10},
#  {'email': 'dudley17@wolff.com',
#   'name': 'Emmett Quigley',
#   'price': 341.96,
#   'quantity': 3},
#  {'email': 'wmiller@gmail.com',
#   'name': 'Jaret Witting II',
#   'price': 944.66,
#   'quantity': 6},
#  {'email': 'zgrimes@yahoo.com',
#   'name': 'Dr. Esteban Hills',
#   'price': 904.6,
#   'quantity': 9},
#  {'email': 'ybatz@yahoo.com',
#   'name': 'Joellen Kertzmann',
#   'price': 319.72,
#   'quantity': 2},
#  {'email': 'kovacekanice@hackett.net',
#   'name': 'Bobby Gerhold',
#   'price': 17.83,
#   'quantity': 5},
#  {'email': 'hershel94@hotmail.com',
#   'name': 'Mr. Raheem Fahey IV',
#   'price': 709.99,
#   'quantity': 3},
#  {'email': 'goldnernona@bradtke.com',
#   'name': 'Miss Kelsi Rodriguez DVM',
#   'price': 689.54,
#   'quantity': 9},
#  {'email': 'damorenathaly@hahn.com',
#   'name': 'Mrs. Lisbeth Hilpert DVM',
#   'price': 426.68,
#   'quantity': 5},
#  {'email': 'bartellpalmer@gmail.com',
#   'name': 'Ressie Kuhlman',
#   'price': 120.67,
#   'quantity': 6},
#  {'email': 'stoltenbergwinter@legros.com',
#   'name': 'Miss Anjelica Kunze',
#   'price': 3.0,
#   'quantity': 8},
#  {'email': 'sarahi60@gmail.com',
#   'name': 'Shantell Waelchi PhD',
#   'price': 543.55,
#   'quantity': 5},
#  {'email': 'ndurgan@hotmail.com',
#   'name': 'Dr. Semaj Renner',
#   'price': 33.37,
#   'quantity': 3},
#  {'email': 'mrau@fadel-frami.net',
#   'name': 'Christa Willms',
#   'price': 159.62,
#   'quantity': 3},
#  {'email': 'uwisozk@gottlieb.biz',
#   'name': 'Ibrahim Rempel Jr.',
#   'price': 331.07,
#   'quantity': 9},
#  {'email': 'gradyhansford@gmail.com',
#   'name': "Miss Marisa O'Hara DDS",
#   'price': 460.18,
#   'quantity': 8},
#  {'email': 'adolphusdaniel@will.org',
#   'name': 'Alvie Hamill',
#   'price': 399.23,
#   'quantity': 1},
#  {'email': 'aurilla68@sipes.com',
#   'name': 'Miss Racheal Moore MD',
#   'price': 120.11,
#   'quantity': 9},
#  {'email': 'josephfarrell@ziemann-hudson.net',
#   'name': 'Docia Koepp',
#   'price': 363.05,
#   'quantity': 7},
#  {'email': 'pansy22@kassulke.com',
#   'name': 'Mr. Rexford Jacobs',
#   'price': 357.6,
#   'quantity': 1},
#  {'email': 'dbauch@stiedemann-leannon.org',
#   'name': 'Joan McGlynn',
#   'price': 301.91,
#   'quantity': 9},
#  {'email': 'myrnahowe@gmail.com',
#   'name': 'Dr. Kaylah Mayer DVM',
#   'price': 122.77,
#   'quantity': 10},
#  {'email': 'arniejast@gmail.com',
#   'name': 'Shoji Langosh',
#   'price': 948.8,
#   'quantity': 5},
#  {'email': 'harryrogahn@larkin.com',
#   'name': 'Mrs. Odalis Baumbach DDS',
#   'price': 431.77,
#   'quantity': 3},
#  {'email': 'matt59@yahoo.com',
#   'name': 'Makenna Wolf',
#   'price': 280.83,
#   'quantity': 7},
#  {'email': 'ohammes@cummerata-rohan.com',
#   'name': 'Margrett Spencer DDS',
#   'price': 274.92,
#   'quantity': 5},
#  {'email': 'dania05@little.com',
#   'name': 'Jagger Conroy',
#   'price': 119.25,
#   'quantity': 10},
#  {'email': 'weaver87@braun-boyer.info',
#   'name': 'Dr. Sandie Koss',
#   'price': 707.77,
#   'quantity': 7},
#  {'email': 'alwine28@bednar-mosciski.net',
#   'name': 'Randi Kub',
#   'price': 5.0,
#   'quantity': 2},
#  {'email': 'dfeil@hotmail.com',
#   'name': 'Mrs. Oneida Mayert PhD',
#   'price': 411.43,
#   'quantity': 3},
#  {'email': 'wschaefer@yahoo.com',
#   'name': 'Effa Rogahn',
#   'price': 431.45,
#   'quantity': 5},
#  {'email': 'lefflerivette@grant.com',
#   'name': 'Abdul Hamill',
#   'price': 568.33,
#   'quantity': 5},
#  {'email': 'goyetteirven@hotmail.com',
#   'name': 'Izabella Armstrong',
#   'price': 265.82,
#   'quantity': 2},
#  {'email': 'ylakin@hagenes-brekke.com',
#   'name': 'Camden Stehr',
#   'price': 805.16,
#   'quantity': 3},
#  {'email': 'devonte56@kerluke-prosacco.info',
#   'name': 'Carlisle Berge',
#   'price': 449.29,
#   'quantity': 2},
#  {'email': 'amberly12@gmail.com',
#   'name': 'Horton Bogisich',
#   'price': 169.37,
#   'quantity': 6},
#  {'email': 'federicowalsh@jerde-stark.biz',
#   'name': 'Loni Beatty',
#   'price': 728.27,
#   'quantity': 1},
#  {'email': 'skylarmayert@conroy.com',
#   'name': 'Needham Kertzmann',
#   'price': 213.62,
#   'quantity': 7},
#  {'email': 'kegan96@yahoo.com',
#   'name': 'Denton Ledner',
#   'price': 109.92,
#   'quantity': 10},
#  {'email': 'dolph07@gmail.com',
#   'name': 'Shelba McCullough',
#   'price': 507.55,
#   'quantity': 7},
#  {'email': 'zainschuppe@baumbach-medhurst.com',
#   'name': 'Jeffery Ebert',
#   'price': 221.31,
#   'quantity': 5},
#  {'email': 'arnoldkreiger@nicolas-damore.com',
#   'name': 'Ford Howell',
#   'price': 689.31,
#   'quantity': 10},
#  {'email': 'johnsonarmida@gmail.com',
#   'name': 'Amirah Feest',
#   'price': 26.8,
#   'quantity': 8},
#  {'email': 'crookstyson@boyer.net',
#   'name': 'Firman Pouros I',
#   'price': 507.3,
#   'quantity': 6},
#  {'email': 'llangworth@hotmail.com',
#   'name': 'Arlan Legros',
#   'price': 865.61,
#   'quantity': 5},
#  {'email': 'kavonmetz@blick-mclaughlin.info',
#   'name': 'Arleth Cruickshank',
#   'price': 431.06,
#   'quantity': 2},
#  {'email': 'jmraz@ebert.com',
#   'name': 'Fernanda Effertz',
#   'price': 202.7,
#   'quantity': 5},
#  {'email': 'eleanorehudson@yahoo.com',
#   'name': 'Wilbert Zulauf',
#   'price': 538.57,
#   'quantity': 8},
#  {'email': 'yostwilma@breitenberg.com',
#   'name': 'Dr. Loren Hand III',
#   'price': 986.55,
#   'quantity': 6},
#  {'email': 'sade46@yahoo.com',
#   'name': 'Attie Stracke DDS',
#   'price': 507.41,
#   'quantity': 6},
#  {'email': 'nkoelpin@romaguera.net',
#   'name': 'Grady Smith',
#   'price': 854.23,
#   'quantity': 8},
#  {'email': 'marty58@yahoo.com',
#   'name': 'Morgan Wunsch',
#   'price': 316.17,
#   'quantity': 10},
#  {'email': 'rdickens@bernhard.com',
#   'name': 'Miss Cleda Skiles PhD',
#   'price': 987.22,
#   'quantity': 4},
#  {'email': 'lynseyankunding@gmail.com',
#   'name': 'Jovita Fritsch DVM',
#   'price': 526.18,
#   'quantity': 4},
#  {'email': 'kaylin67@champlin.net',
#   'name': 'Briana Dare',
#   'price': 989.92,
#   'quantity': 6},
#  {'email': 'mustafa90@gmail.com',
#   'name': 'Ms. Ruby Volkman',
#   'price': 404.61,
#   'quantity': 1},
#  {'email': 'kshlerindasia@gmail.com',
#   'name': 'Miss Keira Effertz MD',
#   'price': 73.64,
#   'quantity': 3},
#  {'email': 'clemmie55@hand.biz',
#   'name': 'Mallory Mayert',
#   'price': 296.78,
#   'quantity': 10},
#  {'email': 'zconnelly@hotmail.com',
#   'name': 'Dr. Veronica Kuvalis MD',
#   'price': 871.37,
#   'quantity': 9},
#  {'email': 'heaneysariah@ritchie-tromp.com',
#   'name': 'Savanah Predovic',
#   'price': 443.14,
#   'quantity': 1},
#  {'email': 'sammy24@yahoo.com',
#   'name': 'Cristen VonRueden',
#   'price': 983.75,
#   'quantity': 6},
#  {'email': 'tillmanthelma@hotmail.com',
#   'name': 'Blanch Wisoky',
#   'price': 903.29,
#   'quantity': 8},
#  {'email': 'kingkamora@koch-rippin.com',
#   'name': 'Elijah Langosh',
#   'price': 18.18,
#   'quantity': 2},
#  {'email': 'kshanahan@reichel.biz',
#   'name': 'Dasia Beahan MD',
#   'price': 340.65,
#   'quantity': 10},
#  {'email': 'oharaskyler@farrell.net',
#   'name': 'Roxann Borer',
#   'price': 720.34,
#   'quantity': 6},
#  {'email': 'heathcotebode@greenholt-kulas.biz',
#   'name': 'Mrs. Rylie Swift',
#   'price': 755.51,
#   'quantity': 8},
#  {'email': 'pollichcarroll@ullrich.com',
#   'name': 'Newt Schultz',
#   'price': 350.14,
#   'quantity': 2},
#  {'email': 'balistrerilouella@yahoo.com',
#   'name': 'Jackson Daugherty',
#   'price': 602.69,
#   'quantity': 5},
#  {'email': 'rowena05@roberts.com',
#   'name': 'Dr. Waino Graham DVM',
#   'price': 915.31,
#   'quantity': 6},
#  {'email': 'abagail98@monahan.com',
#   'name': 'Jarrod Jakubowski',
#   'price': 687.96,
#   'quantity': 10},
#  {'email': 'skoss@yahoo.com',
#   'name': 'Ms. Concetta Emmerich',
#   'price': 847.39,
#   'quantity': 5},
#  {'email': 'pkreiger@simonis.com',
#   'name': 'Austen Balistreri',
#   'price': 941.12,
#   'quantity': 2},
#  {'email': 'htorp@yahoo.com',
#   'name': 'Kiera Gutkowski',
#   'price': 351.43,
#   'quantity': 8},
#  {'email': 'tiara59@yahoo.com',
#   'name': 'Volney Hayes II',
#   'price': 31.39,
#   'quantity': 6},
#  {'email': 'markus91@yahoo.com',
#   'name': 'Palmer Sauer',
#   'price': 897.82,
#   'quantity': 3},
#  {'email': 'laurene43@gmail.com',
#   'name': 'Claudie McClure',
#   'price': 245.96,
#   'quantity': 4},
#  {'email': 'schillerlanette@gmail.com',
#   'name': 'Jerrilyn Morar',
#   'price': 677.92,
#   'quantity': 8},
#  {'email': 'gislasonsherrill@yahoo.com',
#   'name': 'Ronal Streich',
#   'price': 859.49,
#   'quantity': 3},
#  {'email': 'kimberleyhintz@parker.biz',
#   'name': 'Mrs. Lilly Thiel MD',
#   'price': 511.74,
#   'quantity': 2},
#  {'email': 'oharareid@hotmail.com',
#   'name': 'Drew Kautzer',
#   'price': 412.46,
#   'quantity': 9},
#  {'email': 'kharifadel@hotmail.com',
#   'name': 'Alphonso Ankunding',
#   'price': 545.24,
#   'quantity': 7},
#  {'email': 'kpaucek@ward-conn.com',
#   'name': 'Ms. Stacia McDermott',
#   'price': 509.08,
#   'quantity': 8},
#  {'email': 'jean05@yahoo.com',
#   'name': 'Chelsi Towne',
#   'price': 911.29,
#   'quantity': 8},
#  {'email': 'durgantyson@gmail.com',
#   'name': 'Kirk Kovacek',
#   'price': 787.72,
#   'quantity': 5},
#  {'email': 'mafalda01@yahoo.com',
#   'name': 'Jayvion Murazik',
#   'price': 177.58,
#   'quantity': 10},
#  {'email': 'xkautzer@streich.com',
#   'name': 'Adele Blick',
#   'price': 25.03,
#   'quantity': 4},
#  {'email': 'cbotsford@predovic-graham.com',
#   'name': 'Mrs. Christina Botsford MD',
#   'price': 869.06,
#   'quantity': 7},
#  {'email': 'mcculloughyoshio@kshlerin-jakubowski.org',
#   'name': 'Kayson Thompson',
#   'price': 677.74,
#   'quantity': 10},
#  {'email': 'cstoltenberg@daniel.com',
#   'name': 'Dr. Stacy Morissette',
#   'price': 142.3,
#   'quantity': 5},
#  {'email': 'eschumm@gmail.com',
#   'name': 'Margot Nader',
#   'price': 793.88,
#   'quantity': 8},
#  {'email': 'srobel@mclaughlin.net',
#   'name': 'Lovie Klocko DDS',
#   'price': 545.94,
#   'quantity': 4},
#  {'email': 'sreichert@leannon-okon.com',
#   'name': 'Cristian Schneider',
#   'price': 262.3,
#   'quantity': 2},
#  {'email': 'abbottebb@yahoo.com',
#   'name': 'Mariela Goyette',
#   'price': 948.18,
#   'quantity': 4},
#  {'email': 'kundeal@yahoo.com',
#   'name': 'Dariana Walsh',
#   'price': 473.92,
#   'quantity': 5},
#  {'email': 'kailynwolf@metz.com',
#   'name': 'Kameron Brown',
#   'price': 309.47,
#   'quantity': 5},
#  {'email': 'mkessler@yahoo.com',
#   'name': 'Laurie Skiles',
#   'price': 275.9,
#   'quantity': 7},
#  {'email': 'brien46@corwin-rice.info',
#   'name': 'Deja Schulist DVM',
#   'price': 607.49,
#   'quantity': 9},
#  {'email': 'tiara62@hotmail.com',
#   'name': 'Drew White MD',
#   'price': 28.55,
#   'quantity': 8},
#  {'email': 'verdielarkin@windler.com',
#   'name': 'Chrissie Schaefer',
#   'price': 789.83,
#   'quantity': 5},
#  {'email': 'bruendempsey@orn.com',
#   'name': 'Dr. Jaren Vandervort',
#   'price': 608.11,
#   'quantity': 3},
#  {'email': 'duwaynebarton@waelchi.com',
#   'name': 'Byrdie Stiedemann',
#   'price': 930.36,
#   'quantity': 6},
#  {'email': 'dedrickmosciski@gmail.com',
#   'name': 'Sofia Torp',
#   'price': 529.65,
#   'quantity': 7},
#  {'email': 'oralsporer@hotmail.com',
#   'name': 'Bell Heathcote',
#   'price': 806.18,
#   'quantity': 7},
#  {'email': 'ggutkowski@gottlieb.com',
#   'name': 'Dr. Shad Jaskolski II',
#   'price': 647.62,
#   'quantity': 5},
#  {'email': 'evertsatterfield@paucek.org',
#   'name': 'Clem Conroy',
#   'price': 375.95,
#   'quantity': 3},
#  {'email': 'bartonlouann@gusikowski.org',
#   'name': 'Dr. Jann Williamson',
#   'price': 983.34,
#   'quantity': 8},
#  {'email': 'shelvapowlowski@yahoo.com',
#   'name': 'Pallie Schaden PhD',
#   'price': 344.9,
#   'quantity': 5},
#  {'email': 'brakusdarby@hotmail.com',
#   'name': 'Aurelio Stiedemann',
#   'price': 92.36,
#   'quantity': 3},
#  {'email': 'quinnstiedemann@heller.com',
#   'name': 'Miss Ayana Block DVM',
#   'price': 866.26,
#   'quantity': 2},
#  {'email': 'hilleryaufderhar@moen.com',
#   'name': 'Ana Bogisich',
#   'price': 228.44,
#   'quantity': 6},
#  {'email': 'jhowell@ohara.info',
#   'name': 'Lucky Flatley',
#   'price': 273.49,
#   'quantity': 9},
#  {'email': 'tjenkins@greenholt-schmitt.com',
#   'name': 'Mr. Shirley Streich DVM',
#   'price': 523.65,
#   'quantity': 6},
#  {'email': 'ijones@altenwerth.com',
#   'name': 'Shanita Brekke',
#   'price': 682.99,
#   'quantity': 10},
#  {'email': 'dfritsch@hermiston-goodwin.com',
#   'name': 'James Stanton',
#   'price': 656.84,
#   'quantity': 3},
#  {'email': 'sporerjeannie@kautzer.info',
#   'name': 'Jakob Wilkinson',
#   'price': 283.97,
#   'quantity': 4},
#  {'email': 'hmayer@green.info',
#   'name': 'Finley Watsica',
#   'price': 584.25,
#   'quantity': 2},
#  {'email': 'nikolausrichie@halvorson-parker.net',
#   'name': 'Benji Hartmann',
#   'price': 432.75,
#   'quantity': 1},
#  {'email': 'clarkewaelchi@gottlieb-dubuque.com',
#   'name': 'Dr. Charlie Schimmel',
#   'price': 494.23,
#   'quantity': 5},
#  {'email': 'paytonschmeler@barrows.info',
#   'name': 'Encarnacion Stamm',
#   'price': 958.96,
#   'quantity': 6},
#  {'email': 'zhudson@casper.com',
#   'name': 'Maynard Pagac',
#   'price': 517.97,
#   'quantity': 6},
#  {'email': 'blake54@hotmail.com',
#   'name': 'Mr. Taurus Bailey',
#   'price': 845.43,
#   'quantity': 9},
#  {'email': 'wnitzsche@simonis.com',
#   'name': 'Mrs. Corrina Lemke',
#   'price': 93.53,
#   'quantity': 8},
#  {'email': 'dale66@gmail.com',
#   'name': 'Eben Upton',
#   'price': 993.73,
#   'quantity': 1},
#  {'email': 'pernell35@homenick.com',
#   'name': 'Harvie Cruickshank Jr.',
#   'price': 282.61,
#   'quantity': 1},
#  {'email': 'annerreichert@bradtke.com',
#   'name': 'Miss Christine Pollich',
#   'price': 347.71,
#   'quantity': 9},
#  {'email': 'snitzsche@gmail.com',
#   'name': 'Gregory Turner',
#   'price': 224.75,
#   'quantity': 9},
#  {'email': 'erland37@pagac.info',
#   'name': 'Joshua Koepp Sr.',
#   'price': 792.71,
#   'quantity': 5},
#  {'email': 'denesiksavanna@yahoo.com',
#   'name': 'Kendall Lindgren DVM',
#   'price': 150.64,
#   'quantity': 8},
#  {'email': 'donatbernier@schultz.net',
#   'name': "Koby D'Amore",
#   'price': 9.14,
#   'quantity': 1},
#  {'email': 'ijohns@gmail.com',
#   'name': 'Dr. Dovie Rogahn PhD',
#   'price': 110.52,
#   'quantity': 10},
#  {'email': 'kuvalisozella@will.com',
#   'name': 'Mr. Louie Johns V',
#   'price': 267.83,
#   'quantity': 7},
#  {'email': 'mullervalery@glover.info',
#   'name': 'Katelin Schimmel',
#   'price': 292.72,
#   'quantity': 1},
#  {'email': 'adrianne79@bailey-renner.com',
#   'name': 'Miss Lavonne Olson PhD',
#   'price': 580.23,
#   'quantity': 8},
#  {'email': 'nblanda@yahoo.com',
#   'name': 'Delpha Hettinger',
#   'price': 611.3,
#   'quantity': 4},
#  {'email': 'ajafeest@gmail.com',
#   'name': 'Monte Ebert',
#   'price': 332.43,
#   'quantity': 1},
#  {'email': 'benedict45@gmail.com',
#   'name': 'Blaze Dickinson',
#   'price': 746.91,
#   'quantity': 9},
#  {'email': 'kennediwalker@oreilly.com',
#   'name': 'Dr. Dirk Terry',
#   'price': 534.25,
#   'quantity': 1},
#  {'email': 'emoen@price-hegmann.com',
#   'name': 'Mr. Brice Conroy IV',
#   'price': 315.96,
#   'quantity': 6},
#  {'email': 'daughertyshellie@smitham.biz',
#   'name': 'Dillard Renner',
#   'price': 72.49,
#   'quantity': 2},
#  {'email': 'qbailey@donnelly.org',
#   'name': 'Ninnie Herman',
#   'price': 792.39,
#   'quantity': 2},
#  {'email': 'ottiliahilll@gmail.com',
#   'name': 'Sarai Kassulke',
#   'price': 867.45,
#   'quantity': 5},
#  {'email': 'aliapfannerstill@keebler-wolff.com',
#   'name': 'Dominic Jacobson',
#   'price': 249.0,
#   'quantity': 6},
#  {'email': 'kendragrady@yahoo.com',
#   'name': 'Dani Reynolds',
#   'price': 648.66,
#   'quantity': 7},
#  {'email': 'lillia55@yahoo.com',
#   'name': 'Virgie Labadie DVM',
#   'price': 772.73,
#   'quantity': 9},
#  {'email': 'hlang@abbott.com',
#   'name': 'Akeem Brown',
#   'price': 225.55,
#   'quantity': 4},
#  {'email': 'kwitting@gmail.com',
#   'name': 'Jamir Satterfield',
#   'price': 462.06,
#   'quantity': 9},
#  {'email': 'kshlerinlesa@mante.info',
#   'name': 'Dorotha Bernhard',
#   'price': 208.03,
#   'quantity': 4},
#  {'email': 'areliquitzon@gmail.com',
#   'name': 'Oneal Mueller',
#   'price': 711.76,
#   'quantity': 5},
#  {'email': 'krenner@flatley-reilly.com',
#   'name': 'Durell Kassulke',
#   'price': 125.73,
#   'quantity': 1},
#  {'email': 'rayne95@yahoo.com',
#   'name': 'Charlton Volkman',
#   'price': 606.51,
#   'quantity': 8},
#  {'email': 'justen04@kozey.com',
#   'name': 'Mrs. Chanie Hayes',
#   'price': 313.51,
#   'quantity': 1},
#  {'email': 'lacigutmann@hotmail.com',
#   'name': 'Immanuel Schulist',
#   'price': 868.02,
#   'quantity': 3},
#  {'email': 'hrippin@hotmail.com',
#   'name': 'Iza Runolfsson',
#   'price': 439.98,
#   'quantity': 3},
#  {'email': 'daneblick@nolan.com',
#   'name': 'Mrs. Jayde Murphy',
#   'price': 49.67,
#   'quantity': 8},
#  {'email': 'dquigley@hotmail.com',
#   'name': 'Hayward Keebler Jr.',
#   'price': 632.31,
#   'quantity': 8},
#  {'email': 'nohara@hotmail.com',
#   'name': 'Suzan Deckow',
#   'price': 608.57,
#   'quantity': 4},
#  {'email': 'janiyaleannon@towne.com',
#   'name': 'Lenwood Ortiz MD',
#   'price': 380.41,
#   'quantity': 8},
#  {'email': 'senorakoss@hotmail.com',
#   'name': 'Sallie Douglas',
#   'price': 899.45,
#   'quantity': 7},
#  {'email': 'vritchie@gmail.com',
#   'name': 'Jeraldine Dach MD',
#   'price': 111.08,
#   'quantity': 4},
#  {'email': 'tauer@satterfield-jacobi.com',
#   'name': "Caitlyn D'Amore",
#   'price': 103.28,
#   'quantity': 3},
#  {'email': 'beltonsporer@yahoo.com',
#   'name': 'Aliana Muller',
#   'price': 429.62,
#   'quantity': 10},
#  {'email': 'zbode@yahoo.com',
#   'name': 'Marnita Kerluke',
#   'price': 101.49,
#   'quantity': 7},
#  {'email': 'ocieweimann@reichert-leannon.com',
#   'name': 'Wilhelmine Wiegand',
#   'price': 981.88,
#   'quantity': 1},
#  {'email': 'feeneyethyl@hotmail.com',
#   'name': 'Emilie Satterfield',
#   'price': 215.81,
#   'quantity': 10},
#  {'email': 'qvolkman@hotmail.com',
#   'name': 'Mariann Veum',
#   'price': 67.12,
#   'quantity': 2},
#  {'email': 'bergevinson@yahoo.com',
#   'name': 'Jennette Medhurst',
#   'price': 919.37,
#   'quantity': 3},
#  {'email': 'cartermagdalena@hotmail.com',
#   'name': 'Dr. Larissa Watsica DVM',
#   'price': 395.0,
#   'quantity': 9},
#  {'email': 'rparisian@leuschke.com',
#   'name': 'Maritza Jacobson MD',
#   'price': 881.79,
#   'quantity': 5},
#  {'email': 'wolflevon@schiller.com',
#   'name': 'Micaela Dickens DDS',
#   'price': 581.86,
#   'quantity': 8},
#  {'email': 'daisie50@schimmel.com',
#   'name': 'Gail McCullough III',
#   'price': 455.8,
#   'quantity': 5},
#  {'email': 'jonatan05@ortiz-williamson.com',
#   'name': 'Kale Hand',
#   'price': 184.08,
#   'quantity': 2},
#  {'email': 'donnellyhosea@yahoo.com',
#   'name': 'Ms. Hessie Dach',
#   'price': 861.95,
#   'quantity': 8},
#  {'email': 'kesslerarther@johns.org',
#   'name': 'Vick Nader',
#   'price': 699.46,
#   'quantity': 1},
#  {'email': 'dian68@gmail.com',
#   'name': 'Kiya Schoen DVM',
#   'price': 675.82,
#   'quantity': 4},
#  {'email': 'sipessilvio@goodwin.com',
#   'name': 'David Padberg',
#   'price': 796.31,
#   'quantity': 9},
#  {'email': 'osmitham@yahoo.com',
#   'name': 'Gerold Gaylord',
#   'price': 378.72,
#   'quantity': 7},
#  {'email': 'windyebert@yahoo.com',
#   'name': 'Deasia Schmidt',
#   'price': 195.79,
#   'quantity': 3},
#  {'email': 'eloydare@gusikowski-ferry.org',
#   'name': 'Mossie Dach',
#   'price': 683.53,
#   'quantity': 10},
#  {'email': 'rhomenick@lind-cruickshank.com',
#   'name': 'Mr. Ethelbert Bergstrom I',
#   'price': 260.32,
#   'quantity': 2},
#  {'email': 'hhauck@steuber-gorczany.net',
#   'name': 'Dr. Armstead Frami MD',
#   'price': 869.47,
#   'quantity': 7},
#  {'email': 'myrlemraz@gmail.com',
#   'name': 'Calleigh Kiehn DDS',
#   'price': 385.41,
#   'quantity': 2},
#  {'email': 'destineestoltenberg@yahoo.com',
#   'name': 'Lashawn Fahey III',
#   'price': 596.5,
#   'quantity': 8},
#  {'email': 'wfarrell@hahn-wunsch.com',
#   'name': 'Dr. Kelton Doyle',
#   'price': 966.2,
#   'quantity': 9},
#  {'email': 'russelluana@gmail.com',
#   'name': 'Mr. Savion Hane Jr.',
#   'price': 957.29,
#   'quantity': 5},
#  {'email': 'seabornpfannerstill@gmail.com',
#   'name': 'Charle Medhurst',
#   'price': 695.58,
#   'quantity': 10},
#  {'email': 'aurelio61@yahoo.com',
#   'name': 'Emmer Conn',
#   'price': 390.03,
#   'quantity': 5},
#  {'email': 'aryana22@hotmail.com',
#   'name': 'Oscar Kovacek Jr.',
#   'price': 406.92,
#   'quantity': 1},
#  {'email': 'igerhold@bosco.com',
#   'name': 'Octavius Metz',
#   'price': 500.73,
#   'quantity': 9},
#  {'email': 'schinnerleana@stokes.com',
#   'name': 'Delisa Oberbrunner',
#   'price': 45.68,
#   'quantity': 7},
#  {'email': 'howewilda@howell.com',
#   'name': 'Reina Willms',
#   'price': 132.23,
#   'quantity': 7},
#  {'email': 'cordiegreenholt@howell-ferry.org',
#   'name': 'Jerald Gislason',
#   'price': 707.04,
#   'quantity': 8},
#  {'email': 'dickie32@waters.net',
#   'name': 'Miss Drusilla Lehner PhD',
#   'price': 509.93,
#   'quantity': 9},
#  {'email': 'aida96@gmail.com',
#   'name': 'Hiram Robel',
#   'price': 937.49,
#   'quantity': 5},
#  {'email': 'vongrady@hotmail.com',
#   'name': 'Chadd Hartmann',
#   'price': 765.97,
#   'quantity': 10},
#  {'email': 'oberbrunnerclaus@rice.com',
#   'name': 'Tyshawn Herzog',
#   'price': 153.75,
#   'quantity': 6},
#  {'email': 'denakuhlman@pouros.info',
#   'name': 'China Batz PhD',
#   'price': 882.08,
#   'quantity': 8},
#  {'email': 'mquigley@smitham.info',
#   'name': 'Dr. Chesley West IV',
#   'price': 778.22,
#   'quantity': 5},
#  {'email': 'balistrerisylas@schroeder-boehm.info',
#   'name': 'Alyse Stoltenberg',
#   'price': 584.06,
#   'quantity': 8},
#  {'email': 'halvorsonkristyn@hackett.com',
#   'name': 'Dr. Adria Howell DVM',
#   'price': 629.47,
#   'quantity': 1},
#  {'email': 'gnitzsche@bruen.com',
#   'name': 'Celena Stroman PhD',
#   'price': 306.88,
#   'quantity': 7},
#  {'email': 'bmosciski@kshlerin.com',
#   'name': 'Codie Effertz',
#   'price': 925.99,
#   'quantity': 2},
#  {'email': 'rmitchell@sanford-wehner.net',
#   'name': 'Misael Hyatt I',
#   'price': 371.59,
#   'quantity': 1},
#  {'email': 'lossiekoelpin@kozey.info',
#   'name': 'Cherish Bogisich',
#   'price': 146.89,
#   'quantity': 4},
#  {'email': 'hollikrajcik@sanford.net',
#   'name': 'Dr. Carlie Sanford IV',
#   'price': 586.98,
#   'quantity': 3},
#  {'email': 'zwuckert@gmail.com',
#   'name': 'Raelyn Stehr',
#   'price': 531.83,
#   'quantity': 8},
#  {'email': 'abbott90@purdy.com',
#   'name': 'Korbin Upton',
#   'price': 529.79,
#   'quantity': 10},
#  {'email': 'vernerarmstrong@kub.com',
#   'name': 'Antonia Emard',
#   'price': 819.01,
#   'quantity': 8},
#  {'email': 'lowechanda@yahoo.com',
#   'name': 'Odin Rath',
#   'price': 709.94,
#   'quantity': 10},
#  {'email': 'foconnell@luettgen.com',
#   'name': 'Marcia Feest',
#   'price': 123.03,
#   'quantity': 4},
#  {'email': 'tatianalowe@lind-krajcik.biz',
#   'name': 'Shari Wintheiser',
#   'price': 189.35,
#   'quantity': 8},
#  {'email': 'oraynor@wolf.net',
#   'name': 'Mr. Jaeden Ritchie',
#   'price': 94.64,
#   'quantity': 9},
#  {'email': 'schultzbryanna@hotmail.com',
#   'name': 'Elisha Hagenes',
#   'price': 844.89,
#   'quantity': 8},
#  {'email': 'marjory29@morar.com',
#   'name': 'Magdalen Wuckert',
#   'price': 538.45,
#   'quantity': 9},
#  {'email': 'devin02@hotmail.com',
#   'name': 'Jaimee Goodwin',
#   'price': 617.61,
#   'quantity': 7},
#  {'email': 'laceyjacobs@yahoo.com',
#   'name': 'Issac Reichert',
#   'price': 339.17,
#   'quantity': 8},
#  {'email': 'apouros@bosco-dubuque.net',
#   'name': 'Broderick Altenwerth',
#   'price': 374.67,
#   'quantity': 7},
#  {'email': 'fochanderson@effertz.org',
#   'name': 'Skyla Dooley',
#   'price': 215.61,
#   'quantity': 6},
#  {'email': 'harvejones@wilkinson.com',
#   'name': 'Thedore Sanford Jr.',
#   'price': 438.94,
#   'quantity': 2},
#  {'email': 'oconnellallan@gmail.com',
#   'name': 'Jakob Block',
#   'price': 975.43,
#   'quantity': 7},
#  {'email': 'mossieturcotte@hermiston-langworth.com',
#   'name': 'Anson Hoeger',
#   'price': 222.57,
#   'quantity': 9},
#  {'email': 'jfisher@reichert-willms.org',
#   'name': 'Caydence Wolf MD',
#   'price': 128.57,
#   'quantity': 10},
#  {'email': 'braunlorenzo@gottlieb.com',
#   'name': 'Derik Zieme',
#   'price': 587.21,
#   'quantity': 2},
#  {'email': 'tyrajones@yahoo.com',
#   'name': 'Osborn Johnson',
#   'price': 598.99,
#   'quantity': 10},
#  {'email': 'ubrekke@dubuque.com',
#   'name': 'Dr. Odelia Monahan MD',
#   'price': 649.77,
#   'quantity': 9},
#  {'email': 'cherylebotsford@yahoo.com',
#   'name': 'Joellen Hilpert',
#   'price': 368.15,
#   'quantity': 5},
#  {'email': 'drema28@ratke-rau.com',
#   'name': 'Krystin Osinski',
#   'price': 363.71,
#   'quantity': 9},
#  {'email': 'cjohnson@gmail.com',
#   'name': 'Aretha Hilpert',
#   'price': 467.34,
#   'quantity': 2},
#  {'email': 'greenbrittney@hotmail.com',
#   'name': 'Harl Block',
#   'price': 308.91,
#   'quantity': 6},
#  {'email': 'rdooley@gmail.com',
#   'name': 'Nena Durgan',
#   'price': 652.76,
#   'quantity': 5},
#  {'email': 'manningwilderman@yahoo.com',
#   'name': 'Dakoda Ryan DDS',
#   'price': 144.3,
#   'quantity': 7},
#  {'email': 'cody04@parisian-torphy.org',
#   'name': 'Naima Wehner',
#   'price': 724.01,
#   'quantity': 10},
#  {'email': 'legrosenoch@jacobson.org',
#   'name': 'Floy Deckow V',
#   'price': 99.64,
#   'quantity': 4},
#  {'email': 'qdickinson@yahoo.com',
#   'name': 'Carolyn Trantow',
#   'price': 739.48,
#   'quantity': 3},
#  {'email': 'sauerjayson@yahoo.com',
#   'name': 'Garner Christiansen',
#   'price': 493.0,
#   'quantity': 9},
#  {'email': 'gpadberg@kozey.com',
#   'name': 'Mrs. Ocie Lang',
#   'price': 767.48,
#   'quantity': 3},
#  {'email': 'acassin@mann-parker.com',
#   'name': 'Marci Dickens DDS',
#   'price': 909.84,
#   'quantity': 8},
#  {'email': 'vruecker@hotmail.com',
#   'name': 'Assunta Hilpert PhD',
#   'price': 599.73,
#   'quantity': 4},
#  {'email': 'lefflerjaylin@gmail.com',
#   'name': 'Stevan Deckow',
#   'price': 52.43,
#   'quantity': 8},
#  {'email': 'elise25@marvin.com',
#   'name': 'Makala Lind',
#   'price': 937.9,
#   'quantity': 3},
#  {'email': 'dfadel@hotmail.com',
#   'name': 'Fumiko Corwin',
#   'price': 64.63,
#   'quantity': 10},
#  {'email': 'dibbertisadore@lehner.com',
#   'name': 'Reece Abshire',
#   'price': 479.1,
#   'quantity': 4},
#  {'email': 'andrewlockman@yahoo.com',
#   'name': 'Edith Mitchell',
#   'price': 978.78,
#   'quantity': 5},
#  {'email': 'titobernhard@effertz-goyette.net',
#   'name': 'Mrs. Edith Friesen',
#   'price': 483.95,
#   'quantity': 3},
#  {'email': 'isanford@yahoo.com',
#   'name': 'Denese Aufderhar',
#   'price': 540.77,
#   'quantity': 4},
#  {'email': 'jasiah24@torphy.com',
#   'name': 'Olivia Murazik',
#   'price': 937.07,
#   'quantity': 2},
#  {'email': 'evertt76@cummings.org',
#   'name': 'Vincenza Brekke',
#   'price': 931.19,
#   'quantity': 1},
#  {'email': 'aroob@yahoo.com',
#   'name': 'Gavyn Nitzsche',
#   'price': 609.18,
#   'quantity': 9},
#  {'email': 'baron21@rogahn-haley.com',
#   'name': 'Debbra Zemlak',
#   'price': 731.74,
#   'quantity': 2},
#  {'email': 'zweimann@stehr.net',
#   'name': 'Luka Rohan',
#   'price': 119.14,
#   'quantity': 2},
#  {'email': 'gibsonrosemary@hotmail.com',
#   'name': 'Ila Bernhard',
#   'price': 975.28,
#   'quantity': 10},
#  {'email': 'qgleason@yahoo.com',
#   'name': 'Ms. Daniela Gulgowski DVM',
#   'price': 914.93,
#   'quantity': 1},
#  {'email': 'kaya07@gmail.com',
#   'name': 'Olinda Hegmann',
#   'price': 922.95,
#   'quantity': 10},
#  {'email': 'darwynwolf@yahoo.com',
#   'name': 'Shelly Beier',
#   'price': 22.35,
#   'quantity': 10},
#  {'email': 'valentinahane@bosco-effertz.net',
#   'name': 'Lisha McDermott',
#   'price': 693.81,
#   'quantity': 7},
#  {'email': 'icummings@yahoo.com',
#   'name': 'Dr. Shelby McGlynn',
#   'price': 701.13,
#   'quantity': 7},
#  {'email': 'brandi95@swaniawski.com',
#   'name': "Dr. Campbell O'Hara",
#   'price': 238.56,
#   'quantity': 6},
#  {'email': 'ndavis@stroman-bayer.com',
#   'name': 'Hillary Lang',
#   'price': 592.74,
#   'quantity': 1},
#  {'email': 'llegros@gmail.com',
#   'name': 'Alphons Bashirian',
#   'price': 659.62,
#   'quantity': 10},
#  {'email': 'guy64@okuneva.info',
#   'name': 'Clemente Effertz DVM',
#   'price': 415.87,
#   'quantity': 5},
#  {'email': 'jahiemeichmann@lang-connelly.org',
#   'name': 'Dr. Nash Kemmer',
#   'price': 892.46,
#   'quantity': 1},
#  {'email': 'contina70@glover.com',
#   'name': 'Nana Nienow',
#   'price': 160.85,
#   'quantity': 10},
#  {'email': 'qvonrueden@hahn.com',
#   'name': 'Lula Swift',
#   'price': 991.7,
#   'quantity': 4},
#  {'email': 'pkozey@roob.com',
#   'name': 'Ike Marquardt',
#   'price': 892.5,
#   'quantity': 9},
#  {'email': 'losinski@koss.biz',
#   'name': 'Lowell McClure',
#   'price': 233.37,
#   'quantity': 1},
#  {'email': 'flatleyartis@schmitt-swift.net',
#   'name': 'Godfrey Dickinson II',
#   'price': 641.11,
#   'quantity': 7},
#  {'email': 'calebmorissette@mcclure-reichel.com',
#   'name': 'Dedric Koelpin',
#   'price': 443.09,
#   'quantity': 7},
#  {'email': 'cyril52@haley-runolfsson.org',
#   'name': 'Juana Ryan',
#   'price': 348.05,
#   'quantity': 4},
#  {'email': 'homenickderrick@lebsack.org',
#   'name': 'Pearlene Dickinson',
#   'price': 19.16,
#   'quantity': 3},
#  {'email': 'gerholdothel@gmail.com',
#   'name': 'Dr. Jayson Trantow III',
#   'price': 554.38,
#   'quantity': 10},
#  {'email': 'colbert42@balistreri.net',
#   'name': 'Katlin Goodwin',
#   'price': 907.22,
#   'quantity': 8},
#  {'email': 'andersonrena@hotmail.com',
#   'name': 'Makayla Leuschke',
#   'price': 123.39,
#   'quantity': 10},
#  {'email': 'qstokes@maggio.com',
#   'name': 'Lamonte Considine',
#   'price': 724.77,
#   'quantity': 3},
#  {'email': 'kschinner@gmail.com',
#   'name': 'Mitchell Hegmann',
#   'price': 974.72,
#   'quantity': 5},
#  {'email': 'cannonfunk@hotmail.com',
#   'name': 'Ingram Carter',
#   'price': 162.01,
#   'quantity': 1},
#  {'email': 'morarchristy@hotmail.com',
#   'name': 'Mr. Hassan Lebsack Jr.',
#   'price': 857.05,
#   'quantity': 7},
#  {'email': 'dwyane46@farrell-ohara.com',
#   'name': 'Miss Tobi Johnston',
#   'price': 597.36,
#   'quantity': 1},
#  {'email': 'reichelcordella@tillman.com',
#   'name': 'Quinn Johnson MD',
#   'price': 305.13,
#   'quantity': 8},
#  {'email': 'nelle31@yahoo.com',
#   'name': 'Dr. Kunta Hintz',
#   'price': 601.7,
#   'quantity': 2},
#  {'email': 'xroob@gmail.com',
#   'name': 'Delinda Daniel',
#   'price': 83.0,
#   'quantity': 5},
#  {'email': 'wisokyphoenix@hotmail.com',
#   'name': 'Dr. Turner Ankunding IV',
#   'price': 458.77,
#   'quantity': 8},
#  {'email': 'bartontremaine@hotmail.com',
#   'name': 'Mrs. Litzy Hammes DDS',
#   'price': 266.65,
#   'quantity': 3},
#  {'email': 'edward84@hotmail.com',
#   'name': 'Vaughn Runolfsdottir III',
#   'price': 518.48,
#   'quantity': 3},
#  {'email': 'msawayn@hotmail.com',
#   'name': 'Dellar Beatty',
#   'price': 104.33,
#   'quantity': 9},
#  {'email': 'antonhammes@gmail.com',
#   'name': 'Mr. Mckinley Zieme',
#   'price': 652.29,
#   'quantity': 3},
#  {'email': 'kunzekerrie@stark-treutel.com',
#   'name': 'Miss Jazmin Hills PhD',
#   'price': 494.68,
#   'quantity': 9},
#  {'email': 'floretta67@donnelly.net',
#   'name': 'Hadley Braun',
#   'price': 982.19,
#   'quantity': 10},
#  {'email': 'miriah29@yahoo.com',
#   'name': 'Adriene Spencer MD',
#   'price': 26.14,
#   'quantity': 8},
#  {'email': 'glebsack@wunsch.biz',
#   'name': 'Miss Mikalah Heller',
#   'price': 642.53,
#   'quantity': 1},
#  {'email': 'ilangworth@emmerich-mayert.com',
#   'name': 'Claribel Nitzsche',
#   'price': 431.12,
#   'quantity': 2},
#  {'email': 'xkuhlman@hotmail.com',
#   'name': 'Guss Emmerich Sr.',
#   'price': 416.89,
#   'quantity': 8},
#  {'email': 'mable78@yahoo.com',
#   'name': 'Bolden Herman',
#   'price': 12.58,
#   'quantity': 4},
#  {'email': 'ipouros@heller.biz',
#   'name': 'Mr. Samie Ebert',
#   'price': 488.13,
#   'quantity': 5},
#  {'email': 'earlyritchie@purdy.com',
#   'name': 'Jarrett Stark',
#   'price': 448.67,
#   'quantity': 6},
#  {'email': 'moendenise@schmidt.com',
#   'name': 'Lorrie Hills MD',
#   'price': 88.95,
#   'quantity': 5},
#  {'email': 'illa67@keeling.net',
#   'name': 'Earline Howe',
#   'price': 219.64,
#   'quantity': 6},
#  {'email': 'jenelle06@gmail.com',
#   'name': 'Altie Labadie',
#   'price': 632.65,
#   'quantity': 6},
#  {'email': 'cbalistreri@strosin-kirlin.com',
#   'name': 'Rosalia Auer',
#   'price': 896.89,
#   'quantity': 10},
#  {'email': 'carissa09@gmail.com',
#   'name': 'Cleo Stehr',
#   'price': 437.69,
#   'quantity': 9},
#  {'email': 'kevanrenner@gmail.com',
#   'name': 'Almeta Wiegand',
#   'price': 494.35,
#   'quantity': 6},
#  {'email': 'francisconsidine@hotmail.com',
#   'name': 'Beckett Morissette',
#   'price': 299.91,
#   'quantity': 5},
#  {'email': 'wschiller@yahoo.com',
#   'name': 'Dr. Bartley Hermiston',
#   'price': 680.89,
#   'quantity': 7},
#  {'email': 'cwitting@lakin.com',
#   'name': 'Hetty Heathcote',
#   'price': 747.69,
#   'quantity': 7},
#  {'email': 'kulasshasta@yahoo.com',
#   'name': 'Dr. Ether Willms',
#   'price': 606.02,
#   'quantity': 9},
#  {'email': 'laurenerempel@ledner-smith.com',
#   'name': 'Richard Predovic',
#   'price': 363.96,
#   'quantity': 1},
#  {'email': 'vicyweissnat@bailey.com',
#   'name': 'Miss Nallely Rempel PhD',
#   'price': 276.87,
#   'quantity': 10},
#  {'email': 'jule58@mayert-johns.org',
#   'name': 'Darryl Romaguera',
#   'price': 614.16,
#   'quantity': 6},
#  {'email': 'violetta46@gmail.com',
#   'name': 'Lois Labadie',
#   'price': 300.83,
#   'quantity': 5},
#  {'email': 'tbahringer@gmail.com',
#   'name': 'Vincent Kautzer MD',
#   'price': 764.16,
#   'quantity': 4},
#  {'email': 'tilmanbode@leffler-morar.biz',
#   'name': 'Orvin Cremin',
#   'price': 110.99,
#   'quantity': 1},
#  {'email': 'stasia39@labadie.info',
#   'name': 'Birdie Borer',
#   'price': 849.97,
#   'quantity': 8},
#  {'email': 'fmetz@hotmail.com',
#   'name': 'Bobby Emmerich DVM',
#   'price': 618.08,
#   'quantity': 2},
#  {'email': 'ilah71@mcclure.com',
#   'name': 'Dorris Prosacco',
#   'price': 618.65,
#   'quantity': 1},
#  {'email': 'gleasonwilber@gmail.com',
#   'name': 'Trayvon Langworth IV',
#   'price': 44.79,
#   'quantity': 3},
#  {'email': 'dietrichbrant@lemke.org',
#   'name': 'Rebekah Lebsack',
#   'price': 829.92,
#   'quantity': 5},
#  {'email': 'mart03@dicki.biz',
#   'name': 'Mr. Thos Robel',
#   'price': 22.02,
#   'quantity': 7},
#  {'email': 'levilebsack@hotmail.com',
#   'name': 'Taniyah Gleason PhD',
#   'price': 774.77,
#   'quantity': 10},
#  {'email': 'eliza22@hotmail.com',
#   'name': 'Adrian Lehner',
#   'price': 957.5,
#   'quantity': 6},
#  {'email': 'lailaroberts@gmail.com',
#   'name': 'Alyson Abshire PhD',
#   'price': 980.13,
#   'quantity': 10},
#  {'email': 'whowell@gmail.com',
#   'name': 'Wende Fritsch',
#   'price': 345.43,
#   'quantity': 8},
#  {'email': 'gulgowskialisson@bradtke-spinka.com',
#   'name': 'Carsen Schuppe',
#   'price': 264.06,
#   'quantity': 5},
#  {'email': 'swaniawskilloyd@cummerata.info',
#   'name': 'Kaelynn Cummerata',
#   'price': 593.78,
#   'quantity': 7},
#  {'email': 'lynnheller@ernser.info',
#   'name': 'Everett Herzog',
#   'price': 708.06,
#   'quantity': 6},
#  {'email': 'frunte@schaden.com',
#   'name': 'Brant Gusikowski',
#   'price': 482.61,
#   'quantity': 5},
#  {'email': 'billye65@wisozk-wintheiser.org',
#   'name': 'Dr. Mario Howell IV',
#   'price': 406.47,
#   'quantity': 9},
#  {'email': 'drake82@kunde.com',
#   'name': 'Tasia Windler PhD',
#   'price': 44.28,
#   'quantity': 2},
#  {'email': 'calebotsford@grant-swaniawski.org',
#   'name': 'Oneida Wolff',
#   'price': 177.38,
#   'quantity': 5},
#  {'email': 'helenalynch@yahoo.com',
#   'name': 'Capitola Thompson',
#   'price': 311.65,
#   'quantity': 8},
#  {'email': 'glenna41@gmail.com',
#   'name': 'Zachery Hirthe',
#   'price': 697.23,
#   'quantity': 6},
#  {'email': 'ankundingalison@gmail.com',
#   'name': 'Dr. Amaya Hirthe',
#   'price': 690.12,
#   'quantity': 5},
#  {'email': 'avahkutch@gmail.com',
#   'name': 'Derrell Morar',
#   'price': 341.45,
#   'quantity': 6},
#  {'email': 'uklocko@kerluke-mcclure.com',
#   'name': 'Suellen Considine',
#   'price': 237.8,
#   'quantity': 2},
#  {'email': 'adamsrudolph@yahoo.com',
#   'name': 'Declan Mante DVM',
#   'price': 14.61,
#   'quantity': 7},
#  {'email': 'jude57@abbott.com',
#   'name': 'Mr. Felipe Stamm Sr.',
#   'price': 540.29,
#   'quantity': 2},
#  {'email': 'marcie68@bruen-jerde.com',
#   'name': 'Dr. Tayler Wehner',
#   'price': 279.96,
#   'quantity': 5},
#  {'email': 'mquigley@mohr-schultz.com',
#   'name': 'Randolf Quigley',
#   'price': 605.75,
#   'quantity': 10},
#  {'email': 'fnolan@labadie.com',
#   'name': 'Corina Reilly',
#   'price': 165.63,
#   'quantity': 2},
#  {'email': 'icorwin@pfannerstill.com',
#   'name': 'Glendon Kovacek',
#   'price': 412.04,
#   'quantity': 5},
#  {'email': 'ogdendaniel@yahoo.com',
#   'name': 'Brisa Runolfsson',
#   'price': 24.24,
#   'quantity': 2},
#  {'email': 'greengerda@kessler-dietrich.info',
#   'name': 'Rae Hammes',
#   'price': 729.78,
#   'quantity': 2},
#  {'email': 'vonruedendickie@gmail.com',
#   'name': 'Lue Franecki',
#   'price': 250.06,
#   'quantity': 1},
#  {'email': 'schmittjaren@bartoletti.com',
#   'name': 'Merlin Lebsack',
#   'price': 711.61,
#   'quantity': 1},
#  {'email': 'tfadel@ferry.com',
#   'name': 'Linnie Farrell',
#   'price': 353.16,
#   'quantity': 9},
#  {'email': 'champliniverson@hotmail.com',
#   'name': 'Tavion Wolf',
#   'price': 386.66,
#   'quantity': 2},
#  {'email': 'golda71@bins-hessel.com',
#   'name': 'Mrs. Honora Rodriguez',
#   'price': 539.94,
#   'quantity': 1},
#  {'email': 'whitehiram@brakus.com',
#   'name': 'Dr. Babe Conn DVM',
#   'price': 890.73,
#   'quantity': 6},
#  {'email': 'gherman@yahoo.com',
#   'name': 'Dr. Vashon Feil IV',
#   'price': 223.0,
#   'quantity': 1},
#  {'email': 'aurelia33@gmail.com',
#   'name': 'Evangelina Beier',
#   'price': 102.83,
#   'quantity': 5},
#  {'email': 'kevonmarvin@schowalter.net',
#   'name': 'Authur Bartell',
#   'price': 887.09,
#   'quantity': 4},
#  {'email': 'qtreutel@hotmail.com',
#   'name': "Miss Effa O'Keefe",
#   'price': 663.02,
#   'quantity': 10},
#  {'email': 'wisozkgussie@swaniawski.org',
#   'name': 'Brook Carroll',
#   'price': 712.5,
#   'quantity': 9},
#  {'email': 'kossiva@yundt.com',
#   'name': 'Risa Dooley MD',
#   'price': 974.93,
#   'quantity': 10},
#  {'email': 'dessa64@gmail.com',
#   'name': 'Kyara Schultz',
#   'price': 284.76,
#   'quantity': 9},
#  {'email': 'harrishaven@hotmail.com',
#   'name': 'Montana Hudson',
#   'price': 297.7,
#   'quantity': 6},
#  {'email': 'rkreiger@block.com',
#   'name': 'Joretta Bergstrom DVM',
#   'price': 485.38,
#   'quantity': 10},
#  {'email': 'ednahfahey@yahoo.com',
#   'name': 'Loria Boehm',
#   'price': 147.63,
#   'quantity': 7},
#  {'email': 'gunnerpaucek@reynolds-goldner.com',
#   'name': 'Davey Fahey',
#   'price': 372.26,
#   'quantity': 7},
#  {'email': 'bernitahartmann@bogan-cummings.com',
#   'name': 'Dr. Vincenzo Dicki DVM',
#   'price': 869.19,
#   'quantity': 1},
#  {'email': 'ncarroll@conroy.net',
#   'name': 'Emanuel Johnson',
#   'price': 938.89,
#   'quantity': 5},
#  {'email': 'lueilwitzozella@witting.biz',
#   'name': 'Alvie Jakubowski DDS',
#   'price': 751.1,
#   'quantity': 5},
#  {'email': 'khills@howell.info',
#   'name': 'Charolette Doyle',
#   'price': 988.59,
#   'quantity': 8},
#  {'email': 'algiegrady@hotmail.com',
#   'name': 'Teddie Hills',
#   'price': 493.11,
#   'quantity': 8},
#  {'email': 'daija36@wiza.com',
#   'name': 'Rafael Considine',
#   'price': 705.33,
#   'quantity': 9},
#  {'email': 'maybellpagac@hotmail.com',
#   'name': 'Tavon Wiegand',
#   'price': 292.61,
#   'quantity': 1},
#  {'email': 'enicolas@deckow.com',
#   'name': 'Eleonore Eichmann',
#   'price': 617.69,
#   'quantity': 1},
#  {'email': 'ohettinger@nikolaus.com',
#   'name': 'Dr. Chadwick Boyle',
#   'price': 563.55,
#   'quantity': 6},
#  {'email': 'rfeeney@schaden.info',
#   'name': 'Daniela Crist DVM',
#   'price': 233.68,
#   'quantity': 1},
#  {'email': 'rubyebreitenberg@reichert.biz',
#   'name': 'Elgin Thiel',
#   'price': 627.27,
#   'quantity': 3},
#  {'email': 'goyetteabel@wiza.net',
#   'name': 'Somer Keeling',
#   'price': 182.41,
#   'quantity': 10},
#  {'email': 'fitzhughschowalter@ernser.com',
#   'name': 'Nash Treutel',
#   'price': 568.7,
#   'quantity': 2},
#  {'email': 'windlerjaxon@grant-gleichner.net',
#   'name': 'Ms. Dara Hirthe DVM',
#   'price': 95.43,
#   'quantity': 2},
#  {'email': 'hedwig68@gmail.com',
#   'name': 'Dr. Carrie Koepp',
#   'price': 884.72,
#   'quantity': 3},
#  {'email': 'jklocko@hotmail.com',
#   'name': 'Dr. Gustavo Muller',
#   'price': 540.06,
#   'quantity': 6},
#  {'email': 'cherisedietrich@morar-johns.com',
#   'name': 'Alma Raynor',
#   'price': 885.02,
#   'quantity': 4},
#  {'email': 'cmcclure@quigley.info',
#   'name': 'Mrs. Araminta Koepp',
#   'price': 724.96,
#   'quantity': 9},
#  {'email': 'gussiegusikowski@hotmail.com',
#   'name': 'Edison Wunsch',
#   'price': 521.53,
#   'quantity': 3},
#  {'email': 'ronnarice@gmail.com',
#   'name': 'Titus Howe',
#   'price': 687.72,
#   'quantity': 9},
#  {'email': 'valencia06@schneider.org',
#   'name': 'Rennie McClure',
#   'price': 712.32,
#   'quantity': 4},
#  {'email': 'qhagenes@hotmail.com',
#   'name': 'Mr. Marcell Kohler',
#   'price': 41.89,
#   'quantity': 7},
#  {'email': 'dozier20@hotmail.com',
#   'name': 'Macarthur Mann',
#   'price': 149.76,
#   'quantity': 1},
#  {'email': 'kwindler@hotmail.com',
#   'name': 'Merry Prohaska MD',
#   'price': 490.94,
#   'quantity': 2},
#  {'email': 'jayson21@hahn.com',
#   'name': 'Arlyne Batz',
#   'price': 13.58,
#   'quantity': 7},
#  {'email': 'natoshaboyer@witting.net',
#   'name': 'Dr. Eden Turner PhD',
#   'price': 671.35,
#   'quantity': 7},
#  {'email': 'dprosacco@leannon-block.info',
#   'name': 'Rihanna Aufderhar',
#   'price': 740.43,
#   'quantity': 7},
#  {'email': 'zfeeney@tromp.info',
#   'name': 'Tylor Weissnat',
#   'price': 408.32,
#   'quantity': 3},
#  {'email': 'erinmarks@yahoo.com',
#   'name': 'Berdie Schoen PhD',
#   'price': 701.77,
#   'quantity': 1},
#  {'email': 'tondricka@turner.net',
#   'name': 'Adelle Klocko',
#   'price': 831.48,
#   'quantity': 2},
#  {'email': 'zhahn@stanton-rice.com',
#   'name': 'Alysia Carroll',
#   'price': 818.1,
#   'quantity': 7},
# ...
#  {'email': 'vineybernhard@gmail.com',
#   'name': 'Aurelia Weimann',
#   'price': 910.46,
#   'quantity': 2},
#  {'email': 'lavern66@hotmail.com',
#   'name': 'Jerimy Mitchell',
#   'price': 459.22,
#   'quantity': 4},
#  {'email': 'miah35@towne.org',
#   'name': 'Dr. Jarod Daugherty',
#   'price': 951.18,
#   'quantity': 2},
#  {'email': 'vicgreenholt@gutmann-yost.com',
#   'name': 'Mollie Swift',
#   'price': 867.97,
#   'quantity': 5},
#  {'email': 'collinshayden@hotmail.com',
#   'name': 'Mr. Lyric Boehm',
#   'price': 118.23,
#   'quantity': 10},
#  {'email': 'bernhard18@hotmail.com',
#   'name': 'Buck Botsford DDS',
#   'price': 381.58,
#   'quantity': 9},
#  {'email': 'corkerylucindy@quigley.net',
#   'name': 'Knox Rempel',
#   'price': 908.05,
#   'quantity': 10},
#  {'email': 'deantejacobson@yahoo.com',
#   'name': 'Chad Ernser',
#   'price': 67.67,
#   'quantity': 7},
#  {'email': 'evanderschaden@will.info',
#   'name': 'Eddie Nikolaus',
#   'price': 761.4,
#   'quantity': 10},
#  {'email': 'melvina48@haley.biz',
#   'name': 'Pratt Murray',
#   'price': 640.62,
#   'quantity': 3},
#  {'email': 'velva63@hane.biz',
#   'name': 'Bama Bailey DDS',
#   'price': 514.43,
#   'quantity': 2},
#  {'email': 'albina94@morissette-kling.biz',
#   'name': 'Carlisle Zboncak',
#   'price': 33.74,
#   'quantity': 4},
#  {'email': 'lasonya80@kertzmann.com',
#   'name': 'Miss Maybelle Dickens MD',
#   'price': 126.19,
#   'quantity': 9},
#  {'email': 'kingcole@gmail.com',
#   'name': 'Ernst Sauer',
#   'price': 295.07,
#   'quantity': 3},
#  {'email': 'werner59@daniel.biz',
#   'name': 'Tuan Bergnaum',
#   'price': 515.07,
#   'quantity': 9},
#  {'email': 'janicecollins@wuckert.com',
#   'name': 'Bama Mayer',
#   'price': 585.21,
#   'quantity': 4},
#  {'email': 'maurice98@hotmail.com',
#   'name': 'Rolland Koepp',
#   'price': 509.31,
#   'quantity': 4},
#  {'email': 'jamari73@bartell-bogisich.biz',
#   'name': 'Dana Rice MD',
#   'price': 804.38,
#   'quantity': 7},
#  {'email': 'squigley@grimes-witting.com',
#   'name': 'Serina Terry',
#   'price': 949.41,
#   'quantity': 10},
#  {'email': 'volkmanida@hotmail.com',
#   'name': 'Frankie Tromp',
#   'price': 59.09,
#   'quantity': 3},
#  {'email': 'lhermiston@ritchie.com',
#   'name': 'Ms. Lovey Hermiston MD',
#   'price': 412.48,
#   'quantity': 5},
#  {'email': 'deryl78@yahoo.com',
#   'name': 'Ms. Michaele Franecki MD',
#   'price': 83.79,
#   'quantity': 1},
#  {'email': 'gardner48@gmail.com',
#   'name': 'Kirk Wilkinson',
#   'price': 706.62,
#   'quantity': 8},
#  {'email': 'vinceeichmann@gmail.com',
#   'name': 'Adrain Kerluke Jr.',
#   'price': 138.78,
#   'quantity': 3},
#  {'email': 'pweissnat@murray.com',
#   'name': 'Yoel Graham',
#   'price': 840.33,
#   'quantity': 8},
#  {'email': 'gbeier@hotmail.com',
#   'name': 'Juwan Armstrong',
#   'price': 44.0,
#   'quantity': 10},
#  {'email': 'hopperock@barrows.com',
#   'name': 'Tandy Lesch',
#   'price': 859.14,
#   'quantity': 8},
#  {'email': 'shyanne01@yahoo.com',
#   'name': 'Dejuan Schroeder',
#   'price': 584.96,
#   'quantity': 4},
#  {'email': 'slockman@damore.com',
#   'name': "Marley O'Connell",
#   'price': 802.04,
#   'quantity': 4},
#  {'email': 'esanford@hotmail.com',
#   'name': 'Harl Pacocha',
#   'price': 242.4,
#   'quantity': 8},
#  {'email': 'powlowskivincenzo@hotmail.com',
#   'name': 'Kenyon Hamill DDS',
#   'price': 454.49,
#   'quantity': 8},
#  {'email': 'christiansenjeff@yahoo.com',
#   'name': 'Christian Anderson DDS',
#   'price': 705.6,
#   'quantity': 5},
#  {'email': 'domingaemmerich@champlin.com',
#   'name': 'Nohely Lehner',
#   'price': 416.27,
#   'quantity': 8},
#  {'email': 'alayacormier@hotmail.com',
#   'name': 'Delilah Green',
#   'price': 735.27,
#   'quantity': 9},
#  {'email': 'bodekazuo@ohara.com',
#   'name': 'Mr. Harding Predovic',
#   'price': 435.56,
#   'quantity': 5},
#  {'email': 'laureen77@wunsch.info',
#   'name': 'Ms. Helene McDermott PhD',
#   'price': 419.91,
#   'quantity': 8},
#  {'email': 'rasheed93@bernier.biz',
#   'name': 'Mr. Daren Ritchie III',
#   'price': 75.38,
#   'quantity': 8},
#  {'email': 'fritzconroy@hessel.net',
#   'name': 'Keeley Conroy',
#   'price': 108.65,
#   'quantity': 2},
#  {'email': 'wardryland@torphy.org',
#   'name': 'Amari Shields',
#   'price': 224.83,
#   'quantity': 1},
#  {'email': 'kirlinelvia@yahoo.com',
#   'name': 'Miss Lyla Connelly',
#   'price': 134.67,
#   'quantity': 7},
#  {'email': 'kaleenacarroll@aufderhar-roob.com',
#   'name': 'Mr. Alexis Crist PhD',
#   'price': 317.22,
#   'quantity': 9},
#  {'email': 'daijah68@bosco.com',
#   'name': 'Jeramie Jacobi DVM',
#   'price': 123.59,
#   'quantity': 2},
#  {'email': 'odettehettinger@gmail.com',
#   'name': 'Maren Schmeler',
#   'price': 642.9,
#   'quantity': 10},
#  {'email': 'fleet84@yahoo.com',
#   'name': 'Dequan Baumbach',
#   'price': 264.44,
#   'quantity': 9},
#  {'email': 'vonmartin@hotmail.com',
#   'name': 'Dr. Orah Hayes PhD',
#   'price': 494.38,
#   'quantity': 6},
#  {'email': 'millsgene@hotmail.com',
#   'name': 'Dr. Akeelah Kautzer DVM',
#   'price': 998.19,
#   'quantity': 6},
#  {'email': 'reilly00@cole.com',
#   'name': 'Devan Zieme DVM',
#   'price': 315.65,
#   'quantity': 2},
#  {'email': 'larsoncuba@swift-dibbert.com',
#   'name': 'Darold Schoen',
#   'price': 712.36,
#   'quantity': 10},
#  {'email': 'robertooconnell@ankunding.com',
#   'name': 'Deneen Walsh',
#   'price': 833.89,
#   'quantity': 1},
#  {'email': 'daviskelsey@bechtelar.com',
#   'name': 'Alec Treutel',
#   'price': 748.67,
#   'quantity': 7},
#  {'email': 'deedee32@yahoo.com',
#   'name': 'Renae Goyette',
#   'price': 347.33,
#   'quantity': 2},
#  {'email': 'gaylordhence@yahoo.com',
#   'name': 'Dr. Cherise Corkery PhD',
#   'price': 953.35,
#   'quantity': 2},
#  {'email': 'wuckertmaye@hotmail.com',
#   'name': 'Burton Cremin',
#   'price': 552.8,
#   'quantity': 2},
#  {'email': 'twisoky@yahoo.com',
#   'name': 'Angeles Bradtke',
#   'price': 762.93,
#   'quantity': 2},
#  {'email': 'elvinastroman@gmail.com',
#   'name': 'Carmella Adams PhD',
#   'price': 974.05,
#   'quantity': 5},
#  {'email': 'gabriela94@hilll.com',
#   'name': 'Miss Henretta Goodwin',
#   'price': 847.33,
#   'quantity': 6},
#  {'email': 'estokes@oberbrunner.com',
#   'name': 'Kenton Weimann',
#   'price': 589.54,
#   'quantity': 4},
#  {'email': 'ybergstrom@cormier-oreilly.com',
#   'name': 'Jude Yundt I',
#   'price': 264.46,
#   'quantity': 5},
#  {'email': 'hillaryhayes@sawayn.com',
#   'name': 'Brandie Schneider',
#   'price': 561.81,
#   'quantity': 9},
#  {'email': 'juan58@hotmail.com',
#   'name': 'Dorothea Hoppe DVM',
#   'price': 951.98,
#   'quantity': 1},
#  {'email': 'gwalker@kub.info',
#   'name': 'Jere Barton',
#   'price': 534.83,
#   'quantity': 3},
#  {'email': 'osteuber@hotmail.com',
#   'name': 'Mr. Myron Kilback',
#   'price': 64.64,
#   'quantity': 6},
#  {'email': 'leschardell@gleichner.info',
#   'name': 'Mr. Vidal Mertz PhD',
#   'price': 638.16,
#   'quantity': 10},
#  {'email': 'elizabeth43@hettinger.com',
#   'name': 'Ferrell Kertzmann',
#   'price': 760.57,
#   'quantity': 7},
#  {'email': 'ewolff@smith-kerluke.com',
#   'name': 'Werner Cole',
#   'price': 925.01,
#   'quantity': 4},
#  {'email': 'kingclaus@gmail.com',
#   'name': 'Rettie Lindgren',
#   'price': 938.66,
#   'quantity': 3},
#  {'email': 'bethann71@glover.info',
#   'name': 'Kerwin Ferry III',
#   'price': 115.54,
#   'quantity': 3},
#  {'email': 'denzil68@king-mccullough.com',
#   'name': 'Dr. Lakesha Emard',
#   'price': 184.38,
#   'quantity': 4},
#  {'email': 'amasaschneider@windler.com',
#   'name': 'Donna Predovic',
#   'price': 727.17,
#   'quantity': 3},
#  {'email': 'cwindler@hotmail.com',
#   'name': 'Dr. Edsel Ziemann',
#   'price': 751.18,
#   'quantity': 4},
#  {'email': 'herzogwanda@yahoo.com',
#   'name': 'Danica Kutch',
#   'price': 909.93,
#   'quantity': 6},
#  {'email': 'leslie18@yahoo.com',
#   'name': 'Mr. Gerold Tremblay',
#   'price': 856.87,
#   'quantity': 9},
#  {'email': 'jjacobi@goodwin-wyman.biz',
#   'name': 'Tarik Klein',
#   'price': 684.73,
#   'quantity': 6},
#  {'email': 'taina72@gmail.com',
#   'name': 'Karlene Rodriguez',
#   'price': 799.77,
#   'quantity': 4},
#  {'email': 'benardhartmann@smitham.org',
#   'name': 'Mr. Dalton Adams Jr.',
#   'price': 184.73,
#   'quantity': 3},
#  {'email': 'orangetromp@gmail.com',
#   'name': 'Anwar Langosh',
#   'price': 188.09,
#   'quantity': 5},
#  {'email': 'qcollier@ward.net',
#   'name': "Nana O'Connell",
#   'price': 149.43,
#   'quantity': 8},
#  {'email': 'raynorenos@doyle.com',
#   'name': 'Haruko Dibbert DDS',
#   'price': 50.95,
#   'quantity': 4},
#  {'email': 'orpha00@upton-bahringer.org',
#   'name': 'Shanelle Pfeffer',
#   'price': 754.81,
#   'quantity': 3},
#  {'email': 'cruickshankliliana@thompson.biz',
#   'name': 'Caylee Simonis DDS',
#   'price': 295.83,
#   'quantity': 2},
#  {'email': 'wgleichner@jaskolski-shanahan.com',
#   'name': 'Chas Hayes',
#   'price': 612.66,
#   'quantity': 3},
#  {'email': 'bgrady@gmail.com',
#   'name': 'Paxton Cormier',
#   'price': 323.42,
#   'quantity': 10},
#  {'email': 'champlinlollie@kub-eichmann.net',
#   'name': 'Dr. Ritchie Haag',
#   'price': 259.04,
#   'quantity': 10},
#  {'email': 'abernathyhuey@gmail.com',
#   'name': 'Dr. Racheal Lebsack',
#   'price': 342.95,
#   'quantity': 9},
#  {'email': 'amueller@mueller.com',
#   'name': 'Dr. Burleigh Herman Sr.',
#   'price': 268.09,
#   'quantity': 5},
#  {'email': 'yoelbarton@ankunding.com',
#   'name': 'Boris Purdy',
#   'price': 664.91,
#   'quantity': 8},
#  {'email': 'roweetha@gmail.com',
#   'name': 'Inga Hansen',
#   'price': 477.07,
#   'quantity': 8},
#  {'email': 'emilio15@hotmail.com',
#   'name': 'Sandie Bradtke',
#   'price': 801.38,
#   'quantity': 9},
#  {'email': 'ishaan69@yahoo.com',
#   'name': 'Mrs. Jocelynn Watsica',
#   'price': 639.44,
#   'quantity': 3},
#  {'email': 'sokuneva@kassulke-hudson.com',
#   'name': 'Dr. Beatriz Bogan',
#   'price': 645.04,
#   'quantity': 7},
#  {'email': 'myrtagulgowski@hirthe-hyatt.com',
#   'name': 'Ms. Latricia Rowe',
#   'price': 57.91,
#   'quantity': 3},
#  {'email': 'xlindgren@gmail.com',
#   'name': 'Ms. Torie Beer',
#   'price': 990.78,
#   'quantity': 1},
#  {'email': 'vkoss@nolan.com',
#   'name': 'Narcissus Kovacek',
#   'price': 710.26,
#   'quantity': 9},
#  {'email': 'zschaefer@hodkiewicz.com',
#   'name': 'Dr. Mathias Medhurst',
#   'price': 976.97,
#   'quantity': 3},
#  {'email': 'mmarks@hotmail.com',
#   'name': 'Kristoffer Emard I',
#   'price': 88.33,
#   'quantity': 4},
#  {'email': 'bsatterfield@yahoo.com',
#   'name': 'Miss Christel Collier PhD',
#   'price': 915.0,
#   'quantity': 2},
#  {'email': 'eschumm@hotmail.com',
#   'name': 'Luther Harris',
#   'price': 907.86,
#   'quantity': 3},
#  {'email': 'kelleybernier@farrell.net',
#   'name': 'Kaye Zulauf',
#   'price': 11.97,
#   'quantity': 1},
#  {'email': 'clemence82@hotmail.com',
#   'name': 'Pauline Heller',
#   'price': 306.68,
#   'quantity': 2},
#  {'email': 'thedorebeer@hotmail.com',
#   'name': 'Ms. Essence Hane',
#   'price': 511.15,
#   'quantity': 4},
#  {'email': 'dlang@hotmail.com',
#   'name': 'Oral Mayert',
#   'price': 163.51,
#   'quantity': 2},
#  {'email': 'roconner@hyatt.info',
#   'name': 'Normand Bergnaum II',
#   'price': 407.22,
#   'quantity': 9},
#  {'email': 'ilittle@gmail.com',
#   'name': 'Chaya Rau DDS',
#   'price': 190.96,
#   'quantity': 1},
#  {'email': 'sanford52@gmail.com',
#   'name': 'Kathi Bogan DDS',
#   'price': 1.98,
#   'quantity': 10},
#  {'email': 'beerjulien@lowe.com',
#   'name': 'Dr. Cailyn Walker',
#   'price': 152.92,
#   'quantity': 8},
#  {'email': 'dorihansen@hotmail.com',
#   'name': 'Miss Lillia Olson',
#   'price': 421.31,
#   'quantity': 3},
#  {'email': 'lindgrenoctavio@anderson.com',
#   'name': 'Mr. Halbert Schultz II',
#   'price': 512.57,
#   'quantity': 3},
#  {'email': 'celierussel@gmail.com',
#   'name': 'Kerwin Bashirian',
#   'price': 98.28,
#   'quantity': 10},
#  {'email': 'erbyjacobi@hotmail.com',
#   'name': 'Auther Mayer',
#   'price': 592.99,
#   'quantity': 7},
#  {'email': 'nikolausrosendo@gmail.com',
#   'name': 'Less Nienow',
#   'price': 811.37,
#   'quantity': 10},
#  {'email': 'webbhaley@yost.com',
#   'name': 'Ms. Sheyla Bechtelar MD',
#   'price': 247.8,
#   'quantity': 10},
#  {'email': 'russeldinah@padberg-gutmann.com',
#   'name': 'Reynolds Reichel',
#   'price': 662.06,
#   'quantity': 9},
#  {'email': 'lorrainegerlach@blick-bogan.com',
#   'name': 'Dalton Koch',
#   'price': 74.47,
#   'quantity': 2},
#  {'email': 'vgrimes@purdy.com',
#   'name': 'Dr. Kaylie Tillman',
#   'price': 148.01,
#   'quantity': 2},
#  {'email': 'lucretiaemmerich@purdy.com',
#   'name': 'Merle Kohler',
#   'price': 856.67,
#   'quantity': 1},
#  {'email': 'cruz83@collins-wisoky.net',
#   'name': 'Gage Kunde',
#   'price': 168.91,
#   'quantity': 9},
#  {'email': 'ellerysipes@yahoo.com',
#   'name': 'Tammy Treutel DDS',
#   'price': 405.5,
#   'quantity': 5},
#  {'email': 'bergnaumjaqueline@murray.com',
#   'name': 'Steward Kshlerin',
#   'price': 31.1,
#   'quantity': 4},
#  {'email': 'vassie30@borer.com',
#   'name': 'Dr. Darryll Shanahan MD',
#   'price': 222.19,
#   'quantity': 5},
#  {'email': 'wiegandalvy@gmail.com',
#   'name': 'Etter Friesen',
#   'price': 352.54,
#   'quantity': 5},
#  {'email': 'cjacobson@gmail.com',
#   'name': 'Alvia Toy',
#   'price': 507.18,
#   'quantity': 1},
#  {'email': 'lockmanhulda@gmail.com',
#   'name': 'Ms. Arie Goyette',
#   'price': 18.93,
#   'quantity': 1},
#  {'email': 'srunte@yahoo.com',
#   'name': 'Dr. Verlin Kessler',
#   'price': 528.23,
#   'quantity': 10},
#  {'email': 'onikolaus@bechtelar-strosin.org',
#   'name': 'Kory Lowe V',
#   'price': 280.67,
#   'quantity': 3},
#  {'email': 'howellisabela@kunde.biz',
#   'name': 'Mrs. Bailey Okuneva',
#   'price': 1.66,
#   'quantity': 7},
#  {'email': 'finleymitchell@hotmail.com',
#   'name': 'Dr. Haywood Sporer',
#   'price': 576.15,
#   'quantity': 2},
#  {'email': 'kstroman@kautzer.info',
#   'name': 'Barb Senger',
#   'price': 969.55,
#   'quantity': 7},
#  {'email': 'karimfahey@koss.net',
#   'name': 'Richmond Beatty',
#   'price': 675.4,
#   'quantity': 4},
#  {'email': 'dereon14@gmail.com',
#   'name': 'Mrs. Attie Rau',
#   'price': 315.97,
#   'quantity': 1},
#  {'email': 'alaynagleason@hotmail.com',
#   'name': 'Fletcher Feest II',
#   'price': 695.27,
#   'quantity': 3},
#  {'email': 'romacrooks@gmail.com',
#   'name': 'Lew Bartoletti PhD',
#   'price': 858.8,
#   'quantity': 6},
#  {'email': 'zernser@yahoo.com',
#   'name': 'Cornelius Pagac',
#   'price': 916.22,
#   'quantity': 3},
#  {'email': 'dorine02@gmail.com',
#   'name': 'Miss Janel Schuster DVM',
#   'price': 787.41,
#   'quantity': 6},
#  {'email': 'lambert74@stehr-daugherty.com',
#   'name': 'Mr. Jewell Nikolaus Sr.',
#   'price': 496.32,
#   'quantity': 9},
#  {'email': 'idamaeschulist@paucek-ohara.com',
#   'name': 'Mrs. Elva Waters',
#   'price': 370.37,
#   'quantity': 7},
#  {'email': 'fleda26@gmail.com',
#   'name': 'Mr. Dustin Bayer',
#   'price': 268.2,
#   'quantity': 1},
#  {'email': 'kjakubowski@hotmail.com',
#   'name': 'Miss Arlyne Armstrong MD',
#   'price': 65.44,
#   'quantity': 10},
#  {'email': 'idahegmann@gmail.com',
#   'name': 'Eliezer Renner',
#   'price': 990.57,
#   'quantity': 2},
#  {'email': 'alceecorwin@gmail.com',
#   'name': 'Rush Spinka',
#   'price': 346.53,
#   'quantity': 4},
#  {'email': 'hellerhayden@hotmail.com',
#   'name': 'Shiela Walter DVM',
#   'price': 294.65,
#   'quantity': 6},
#  {'email': 'hallie33@schaden.net',
#   'name': 'Mrs. Cristen Swift PhD',
#   'price': 807.89,
#   'quantity': 8},
#  {'email': 'richellecummings@feest.info',
#   'name': 'Sampson Kozey III',
#   'price': 487.43,
#   'quantity': 3},
#  {'email': 'rboehm@gmail.com',
#   'name': 'Robert Smitham',
#   'price': 717.47,
#   'quantity': 3},
#  {'email': 'lennymcglynn@zieme.com',
#   'name': 'Yasmine Jast',
#   'price': 808.6,
#   'quantity': 4},
#  {'email': 'powlowskiciara@lockman.com',
#   'name': 'Champ Hessel',
#   'price': 364.64,
#   'quantity': 1},
#  {'email': 'augustine15@torp.com',
#   'name': 'Angelina Larkin DDS',
#   'price': 678.16,
#   'quantity': 5},
#  {'email': 'sharita85@gmail.com',
#   'name': 'Winnifred Goldner',
#   'price': 885.51,
#   'quantity': 5},
#  {'email': 'woodrowhermiston@anderson.com',
#   'name': 'Winnifred Wiza',
#   'price': 687.32,
#   'quantity': 10},
#  {'email': 'akreiger@windler.com',
#   'name': 'Adriana Roberts MD',
#   'price': 67.51,
#   'quantity': 8},
#  {'email': 'kala06@yahoo.com',
#   'name': 'Dorcas Schaefer',
#   'price': 472.8,
#   'quantity': 7},
#  {'email': 'sjohnston@hotmail.com',
#   'name': 'Casimer Stracke',
#   'price': 949.94,
#   'quantity': 8},
#  {'email': 'kkuhlman@sanford-lubowitz.com',
#   'name': 'Walker Hagenes Sr.',
#   'price': 992.35,
#   'quantity': 7},
#  {'email': 'lkihn@stark.com',
#   'name': 'Yetta Corkery MD',
#   'price': 653.87,
#   'quantity': 8},
#  {'email': 'itromp@gmail.com',
#   'name': 'Taylor Strosin',
#   'price': 149.58,
#   'quantity': 8}]
