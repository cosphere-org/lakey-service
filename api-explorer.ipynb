# %%
import requests
from IPython.core.display import display, HTML

# %% [markdown]
# # ENTRYPOINT

# %%
response = requests.get('http://127.0.0.1:8887')

commands = response.json()['commands']

# %%
sorted(commands.keys())
# Out:
# ['ATTACH_ACCOUNT_TO_AUTH_REQUEST',
#  'BULK_READ_CATALOGUEITEMS',
#  'BULK_READ_DOWNLOADREQUESTS',
#  'CREATE_AUTH_REQUEST',
#  'CREATE_AUTH_TOKEN',
#  'CREATE_CATALOGUEITEM',
#  'DELETE_CATALOGUEITEM',
#  'DELETE_DOWNLOADREQUEST',
#  'ESTIMATE_SIZE_OF_DOWNLOAD_REQUEST',
#  'READ_CATALOGUEITEM',
#  'READ_DOWNLOADREQUEST',
#  'READ_ENTRY_POINT',
#  'READ_OR_CREATE_DOWNLOADREQUEST',
#  'RENDER_AUTH_REQUEST_AUTHENTICATE_UI',
#  'RENDER_DOWNLOAD_REQUEST_UI_DATA',
#  'UPDATE_CATALOGUEITEM',
#  'WITH_SAMPLE_AND_DISTRIBUTION_UPDATE_CATALOGUEITEM']

# %%
commands['DELETE_DOWNLOADREQUEST']
# Out:
# {'method': 'delete',
#  'path_conf': {'path': '/downloader/requests/{request_id}',
#   'parameters': [{'name': 'request_id',
#     'type': 'integer',
#     'description': ''}]},
#  'meta': {'title': 'Creator can cancel request or remove himself from waiters',
#   'description': None,
#   'domain': {'id': 'download_requests',
#    'name': 'Download Requests Management',
#    '@type': 'domain'},
#   '@type': 'meta'},
#  'access': {'access_list': ['RESEARCHER', 'ADMIN'],
#   'is_private': False,
#   'is_external': False,
#   '@type': 'access'},
#  'source': {'filepath': '/lakey_service/downloader/commands.py',
#   'start_line': 175,
#   'end_line': 196,
#   '@type': 'source'},
#  'schemas': {'output': {'uri': 'https://github.com/cosphere-org/lakey-service/blob/0cb3db31c6dea7788dbbdb1f01a940180005acb4/.venv/lib/python3.7/site-packages/lily/base/serializers.py/#L180',
#    'schema': {'type': 'object',
#     'required': [],
#     'properties': {},
#     'entity_type': 'empty'}}},
#  'examples': {},
#  '@type': 'command'}

# %% [markdown]
# ## Create Auth Token
#
# In the console:
#
# ```bash
# source env.sh && python lakey_service/manage.py create_account johnny@where.com --type ADMIN
# source env.sh && python lakey_service/manage.py create_auth_token johnny@where.com
# ```

# %%
AUTH_TOKEN = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpZCI6MywiZW1haWwiOiJqb2hubnlAd2hlcmUuY29tIiwidHlwZSI6IkFETUlOIiwiZXhwIjoxNTY3MDc4MjY2fQ.geEEnLBloi99sJLoQcVCMcCISyoM82qjTSOinK577fU'

# %% [markdown]
# # BULK READ CATALOGUE ITEM

# %%
response = requests.get(
    'http://127.0.0.1:8887/catalogue/items/',
    headers={
        'Authorization': f'Bearer {AUTH_TOKEN}'
    })

response.json()
# Out:
# {'items': [{'id': 2,
#    'name': 'iot.features',
#    'spec': [{'name': 'gateway_uuid',
#      'size': None,
#      'type': 'STRING',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'timestamp',
#      'size': None,
#      'type': 'DATETIME',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'property',
#      'size': None,
#      'type': 'STRING',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'value',
#      'size': None,
#      'type': 'FLOAT',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'month',
#      'size': None,
#      'type': 'INTEGER',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'day',
#      'size': None,
#      'type': 'INTEGER',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None}],
#    'sample': [],
#    'executor_type': 'ATHENA',
#    'created_by': None,
#    'updated_by': None,
#    'maintained_by': None,
#    '@type': 'catalogue_item'},
#   {'id': 3,
#    'name': 'iot.devices',
#    'spec': [{'name': 'gateway_uuid',
#      'size': None,
#      'type': 'STRING',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'geo_lat',
#      'size': None,
#      'type': 'FLOAT',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'geo_lng',
#      'size': None,
#      'type': 'FLOAT',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'zip_code',
#      'size': None,
#      'type': 'STRING',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None}],
#    'sample': [],
#    'executor_type': 'ATHENA',
#    'created_by': None,
#    'updated_by': None,
#    'maintained_by': None,
#    '@type': 'catalogue_item'},
#   {'id': 4,
#    'name': 'external.weather',
#    'spec': [{'name': 'zip_code',
#      'size': None,
#      'type': 'STRING',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'obs_geo_lat',
#      'size': None,
#      'type': 'FLOAT',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'obs_geo_lng',
#      'size': None,
#      'type': 'FLOAT',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'obs_name',
#      'size': None,
#      'type': 'STRING',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'timestamp',
#      'size': None,
#      'type': 'DATETIME',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'temp',
#      'size': None,
#      'type': 'FLOAT',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None}],
#    'sample': [],
#    'executor_type': 'ATHENA',
#    'created_by': None,
#    'updated_by': None,
#    'maintained_by': None,
#    '@type': 'catalogue_item'},
#   {'id': 5,
#    'name': 'sap.sales',
#    'spec': [{'name': 'product',
#      'size': None,
#      'type': 'STRING',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'obs_geo_lat',
#      'size': None,
#      'type': 'FLOAT',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'client_id',
#      'size': None,
#      'type': 'INTEGER',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'sold_datetime',
#      'size': None,
#      'type': 'DATETIME',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None}],
#    'sample': [],
#    'executor_type': 'ATHENA',
#    'created_by': None,
#    'updated_by': None,
#    'maintained_by': None,
#    '@type': 'catalogue_item'},
#   {'id': 6,
#    'name': 'sap.client',
#    'spec': [{'name': 'name',
#      'size': None,
#      'type': 'STRING',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'client_id',
#      'size': None,
#      'type': 'INTEGER',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'sap_id',
#      'size': None,
#      'type': 'INTEGER',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None}],
#    'sample': [],
#    'executor_type': 'ATHENA',
#    'created_by': None,
#    'updated_by': None,
#    'maintained_by': None,
#    '@type': 'catalogue_item'},
#   {'id': 7,
#    'name': 'google_analytics.website_stats',
#    'spec': [{'name': 'url',
#      'size': None,
#      'type': 'STRING',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'click_element',
#      'size': None,
#      'type': 'STRING',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'click_datetime',
#      'size': None,
#      'type': 'DATETIME',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None}],
#    'sample': [],
#    'executor_type': 'ATHENA',
#    'created_by': None,
#    'updated_by': None,
#    'maintained_by': None,
#    '@type': 'catalogue_item'},
#   {'id': 8,
#    'name': 'iot operational data',
#    'spec': [{'name': 'property',
#      'size': 190234,
#      'type': 'STRING',
#      'is_enum': True,
#      'description': 'what event type are we dealing with',
#      'is_nullable': False,
#      'distribution': [{'count': 134, 'value': 'outside.temperature/value'},
#       {'count': 6789, 'value': 'inside.temperature/value'},
#       {'count': 567, 'value': 'super.pressure/value'},
#       {'count': 12, 'value': 'normal.pressure/value'},
#       {'count': 671, 'value': 'wifi.strength/value'},
#       {'count': 12, 'value': 'wifi.weakness/value'}]},
#     {'name': 'value',
#      'size': 67,
#      'type': 'FLOAT',
#      'is_enum': False,
#      'description': 'the value of a particular property',
#      'is_nullable': True,
#      'distribution': [{'count': 56, 'value': 1.0},
#       {'count': 567, 'value': 2.0},
#       {'count': 567, 'value': 4.0},
#       {'count': 1235, 'value': 34.0},
#       {'count': 8799, 'value': 45.0}]}],
#    'sample': [{'value': 1.2, 'property': 'wifi.strength/value'},
#     {'value': 48.1, 'property': 'normal.pressure/value'},
#     {'value': 56.6, 'property': 'inside.temperature/value'},
#     {'value': 345.1, 'property': 'inside.temperature/value'},
#     {'value': 1.21, 'property': 'inside.temperature/value'},
#     {'value': 19.1, 'property': 'normal.pressure/value'}],
#    'executor_type': 'DATABRICKS',
#    'created_by': None,
#    'updated_by': None,
#    'maintained_by': {'id': 1,
#     'email': 'maciej@cosphere.org',
#     'type': 'ADMIN',
#     '@type': 'account'},
#    '@type': 'catalogue_item'},
#   {'id': 9,
#    'name': 'sales data',
#    'spec': [{'name': 'client_id',
#      'size': 190234,
#      'type': 'STRING',
#      'is_enum': False,
#      'description': 'the unique identifier of the client',
#      'is_nullable': False,
#      'distribution': [{'count': 1342, 'value': 'jacky.1'},
#       {'count': 6789, 'value': 'johnny.12'},
#       {'count': 567, 'value': 'bobby.4'}]},
#     {'name': 'paid',
#      'size': 67,
#      'type': 'FLOAT',
#      'is_enum': False,
#      'description': 'amount of money paid',
#      'is_nullable': True,
#      'distribution': [{'count': 56, 'value': 1.0},
#       {'count': 567, 'value': 2.0},
#       {'count': 567, 'value': 4.0},
#       {'count': 1235, 'value': 34.0},
#       {'count': 8799, 'value': 45.0}]},
#     {'name': 'currency',
#      'size': 67,
#      'type': 'STRING',
#      'is_enum': False,
#      'description': 'currency in which payment occurred',
#      'is_nullable': True,
#      'distribution': [{'count': 563, 'value': 'EUR'},
#       {'count': 567, 'value': 'USD'},
#       {'count': 567, 'value': 'PLN'}]}],
#    'sample': [{'paid': 112.25, 'currency': 'EUR', 'client_id': 'jacky.2'},
#     {'paid': 4500.0, 'currency': 'PLN', 'client_id': 'alice.2'},
#     {'paid': 56.78, 'currency': 'USD', 'client_id': 'john.567'}],
#    'executor_type': 'DATABRICKS',
#    'created_by': None,
#    'updated_by': None,
#    'maintained_by': {'id': 1,
#     'email': 'maciej@cosphere.org',
#     'type': 'ADMIN',
#     '@type': 'account'},
#    '@type': 'catalogue_item'},
#   {'id': 10,
#    'name': '2_column',
#    'spec': [{'name': 'A',
#      'size': 8000080,
#      'type': 'INTEGER',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': [{'count': 40, 'value_max': 21, 'value_min': 1},
#       {'count': 1546, 'value_max': 41, 'value_min': 21},
#       {'count': 23928, 'value_max': 61, 'value_min': 41},
#       {'count': 144995, 'value_max': 81, 'value_min': 61},
#       {'count': 348443, 'value_max': 101, 'value_min': 81},
#       {'count': 333839, 'value_max': 121, 'value_min': 101},
#       {'count': 126904, 'value_max': 141, 'value_min': 121},
#       {'count': 19179, 'value_max': 161, 'value_min': 141},
#       {'count': 1101, 'value_max': 181, 'value_min': 161},
#       {'count': 25, 'value_max': 201, 'value_min': 181}]},
#     {'name': 'B',
#      'size': 8000080,
#      'type': 'INTEGER',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': [{'count': 21, 'value_max': 118, 'value_min': 97},
#       {'count': 1120, 'value_max': 139, 'value_min': 118},
#       {'count': 21361, 'value_max': 160, 'value_min': 139},
#       {'count': 148854, 'value_max': 181, 'value_min': 160},
#       {'count': 368067, 'value_max': 202, 'value_min': 181},
#       {'count': 334972, 'value_max': 223, 'value_min': 202},
#       {'count': 111566, 'value_max': 244, 'value_min': 223},
#       {'count': 13464, 'value_max': 265, 'value_min': 244},
#       {'count': 560, 'value_max': 286, 'value_min': 265},
#       {'count': 15, 'value_max': 307, 'value_min': 286}]}],
#    'sample': [],
#    'executor_type': 'LOCAL',
#    'created_by': None,
#    'updated_by': None,
#    'maintained_by': None,
#    '@type': 'catalogue_item'}],
#  '@type': 'catalogue_items_list',
#  '@event': 'CATALOGUEITEMS_BULK_READ'}

# %% [markdown]
# # CREATE CATALOGUE ITEM

# %%
response = requests.post(
    'http://127.0.0.1:8887/catalogue/items/',
    headers={
        'Authorization': f'Bearer {AUTH_TOKEN}'
    },
    json={
        "name": "iot_events2",
        "sample": [],
        "spec": [
            {
                "name": "value",
                "type": "FLOAT",
                "size": 19203,
                "is_nullable": False,
                "is_enum": False,
                "distribution": None
            }
        ],
        "maintained_by_id": 1,
        "executor_type": "DATABRICKS"
    },
)
response.json()
# Out:
# {'@type': 'error', '@event': 'AUTH_TOKEN_MISSING_ACCOUNT'}

# %% [markdown]
# # READ_CATALOGUEITEM

# %%
response = requests.get(
    'http://127.0.0.1:8887/catalogue/items/11',
    headers={
        'Authorization': f'Bearer {AUTH_TOKEN}'
    },
)
response.json()
# Out:
# {'@type': 'error', '@event': 'AUTH_TOKEN_MISSING_ACCOUNT'}

# %% [markdown]
# # UPDATE_CATALOGUEITEM

# %%
response = requests.put(
    'http://127.0.0.1:8887/catalogue/items/10',
    headers={
        'Authorization': f'Bearer {AUTH_TOKEN}'
    },
    data=json.dumps({
        'name': 'sales data',
         'spec': [{'name': 'client_id',
           'size': 190234,
           'type': 'STRING',
           'is_enum': False,
           'description': 'the unique identifier of the client',
           'is_nullable': False,
           'distribution': [
            {'count': 1342, 'value_min': 'jacky.1', 'value_max': 'jacky.2'},
            {'count': 6789, 'value_min': 'johnny.12', 'value_min': 'johnny.22'},
            {'count': 567, 'value_min': 'bobby.4', 'value_max': 'bobby.5'}]},
          {'name': 'paid',
           'size': 67,
           'type': 'FLOAT',
           'is_enum': False,
           'description': 'amount of money paid',
           'is_nullable': True,
           'distribution': [
            {'count': 56, 'value_min': 1.0, 'value_max': 1.0},
            {'count': 567, 'value_min': 2.0, 'value_max': 3.0},
            {'count': 567, 'value_min': 4.0, 'value_max': 5.0},
            {'count': 1235, 'value_min': 34.0, 'value_max': 50.0},
            {'count': 8799, 'value_min': 45.0, 'value_max': 55.0}]},
          {'name': 'currency',
           'size': 67,
           'type': 'STRING',
           'is_enum': False,
           'description': 'currency in which payment occurred',
           'is_nullable': True,
           'distribution': [
            {'count': 563, 'value_min': 'EUR', 'value_max': 'EUR'},
            {'count': 567, 'value_min': 'USD', 'value_max': 'USD'},
            {'count': 567, 'value_min': 'PLN', 'value_max': 'PLN'}]}],
    })
)
response.json()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-a24e7193e41f> in <module>
#       4         'Authorization': f'Bearer {AUTH_TOKEN}'
#       5     },
# ----> 6     data=json.dumps({
#       7         'name': 'sales data',
#       8          'spec': [{'name': 'client_id',
#
# NameError: name 'json' is not defined

# %% [markdown]
# # DELETE_CATALOGUEITEM

# %%
response = requests.delete(
    'http://127.0.0.1:8887/catalogue/items/1',
    headers={
        'Authorization': f'Bearer {AUTH_TOKEN}'
    },
)
response.json()
# Out:
# {'@type': 'error', '@event': 'AUTH_TOKEN_MISSING_ACCOUNT'}

# %% [markdown]
# # RENDER_AUTH_REQUEST_AUTHENTICATE_UI

# %%
response = requests.get(
    'http://127.0.0.1:8887/accounts/auth_requests/62/authenticate/ui/',
    headers={
        'Authorization': f'Bearer {AUTH_TOKEN}'
    },
    data=json.dumps({
        "catalogue_item_id": 62
    })
)

response
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-d3bf47d3b087> in <module>
#       4         'Authorization': f'Bearer {AUTH_TOKEN}'
#       5     },
# ----> 6     data=json.dumps({
#       7         "catalogue_item_id": 62
#       8     })
#
# NameError: name 'json' is not defined

# %%
display(HTML('<!DOCTYPE html>\n<html>\n    <head>\n        <title>Lakey Authentication</title>\n        <meta\n            name="google-signin-client_id"\n            content="to.be.overwritten">\n\n        <link\n            href="https://fonts.googleapis.com/css?family=IBM+Plex+Sans"\n            rel="stylesheet">\n        <style>\n            body {\n                background: #e4e4e4;\n            }\n\n            #main {\n                height: 200px;\n                width: 100%;\n                font-family: \'IBM Plex Sans\', sans-serif;\n            }\n\n            h2 {\n                font-weight: normal;\n            }\n\n            #authenticate, #done, #wait {\n                display: flex;\n                flex-direction: column;\n                align-items: center;\n                justify-content: center;\n            }\n\n            #done, #wait {\n                display: none;\n            }\n        </style>\n        <script\n            type="text/javascript">\n\n\n            function renderButton() {\n                gapi.signin2.render(\'google-auth-button\', {\n                    \'scope\': \'profile email\',\n                    \'width\': 240,\n                    \'height\': 50,\n                    \'longtitle\': true,\n                    \'theme\': \'dark\',\n                    \'onsuccess\': onSuccess,\n                    \'onfailure\': onFailure\n              });\n            }\n\n            function onSuccess(googleUser) {\n                let $done = document.getElementById(\'done\');\n                let $wait = document.getElementById(\'wait\');\n                let $authenticate = document.getElementById(\'authenticate\');\n\n                let authRequestUUID = \'62\';\n                let profile = googleUser.getBasicProfile();\n\n                let xhr = new XMLHttpRequest();\n                xhr.open(\n                    \'POST\',\n                    \'/accounts/auth_requests/attach_account/\');\n\n                xhr.setRequestHeader(\n                    "Content-Type", "application/json;charset=UTF-8");\n\n                xhr.send(\n                    JSON.stringify({\n                        request_uuid: authRequestUUID,\n                        oauth_token: googleUser.getAuthResponse().id_token,\n                        email: profile.getEmail(),\n                    })\n                );\n\n                // -- hide AUTHENTICATE view and show WAIT view\n                $authenticate.style[\'display\'] = \'none\';\n                $wait.style[\'display\'] = \'flex\';\n\n                xhr.onload = () => {\n                    // -- hide WAIT view and show DONE view\n                    $wait.style[\'display\'] = \'none\';\n                    $done.style[\'display\'] = \'flex\';\n                };\n            }\n\n            function onFailure(error) {\n                console.error(error);\n            }\n\n        </script>\n        <script\n            src="https://apis.google.com/js/platform.js?onload=renderButton"\n            async\n            defer>\n        </script>\n    </head>\n\n    <body>\n\n        <div\n            id="main">\n            <div\n                id="authenticate">\n\n                <h2>Sign In To Lakey</h2>\n                <div\n                    id="google-auth-button"></div>\n            </div>\n\n            <div\n                id="wait">\n\n                PLEASE WAIT ...\n            </div>\n\n            <div\n                id="done">\n\n                DONE, PLEASE RUN AGAIN CODE THAT GOT YOU HERE.\n            </div>\n\n        </div>\n    </body>\n\n</html>\n'))
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Lakey Authentication</title>
#         <meta
#             name="google-signin-client_id"
#             content="to.be.overwritten">
#
#         <link
#             href="https://fonts.googleapis.com/css?family=IBM+Plex+Sans"
#             rel="stylesheet">
#         <style>
#             body {
#                 background: #e4e4e4;
#             }
#
#             #main {
#                 height: 200px;
#                 width: 100%;
#                 font-family: 'IBM Plex Sans', sans-serif;
#             }
#
#             h2 {
#                 font-weight: normal;
#             }
#
#             #authenticate, #done, #wait {
#                 display: flex;
#                 flex-direction: column;
#                 align-items: center;
#                 justify-content: center;
#             }
#
#             #done, #wait {
#                 display: none;
#             }
#         </style>
#         <script
#             type="text/javascript">
#
#
#             function renderButton() {
#                 gapi.signin2.render('google-auth-button', {
#                     'scope': 'profile email',
#                     'width': 240,
#                     'height': 50,
#                     'longtitle': true,
#                     'theme': 'dark',
#                     'onsuccess': onSuccess,
#                     'onfailure': onFailure
#               });
#             }
#
#             function onSuccess(googleUser) {
#                 let $done = document.getElementById('done');
#                 let $wait = document.getElementById('wait');
#                 let $authenticate = document.getElementById('authenticate');
#
#                 let authRequestUUID = '62';
#                 let profile = googleUser.getBasicProfile();
#
#                 let xhr = new XMLHttpRequest();
#                 xhr.open(
#                     'POST',
#                     '/accounts/auth_requests/attach_account/');
#
#                 xhr.setRequestHeader(
#                     "Content-Type", "application/json;charset=UTF-8");
#
#                 xhr.send(
#                     JSON.stringify({
#                         request_uuid: authRequestUUID,
#                         oauth_token: googleUser.getAuthResponse().id_token,
#                         email: profile.getEmail(),
#                     })
#                 );
#
#                 // -- hide AUTHENTICATE view and show WAIT view
#                 $authenticate.style['display'] = 'none';
#                 $wait.style['display'] = 'flex';
#
#                 xhr.onload = () => {
#                     // -- hide WAIT view and show DONE view
#                     $wait.style['display'] = 'none';
#                     $done.style['display'] = 'flex';
#                 };
#             }
#
#             function onFailure(error) {
#                 console.error(error);
#             }
#
#         </script>
#         <script
#             src="https://apis.google.com/js/platform.js?onload=renderButton"
#             async
#             defer>
#         </script>
#     </head>
#
#     <body>
#
#         <div
#             id="main">
#             <div
#                 id="authenticate">
#
#                 <h2>Sign In To Lakey</h2>
#                 <div
#                     id="google-auth-button"></div>
#             </div>
#
#             <div
#                 id="wait">
#
#                 PLEASE WAIT ...
#             </div>
#
#             <div
#                 id="done">
#
#                 DONE, PLEASE RUN AGAIN CODE THAT GOT YOU HERE.
#             </div>
#
#         </div>
#     </body>
#
# </html>

# %% [markdown]
# # CREATE_AUTH_REQUEST

# %%
response = requests.post(
    'http://127.0.0.1:8887/accounts/auth_requests/',
    headers={
        'Authorization': f'Bearer {AUTH_TOKEN}'
    },
    data=json.dumps({
        'account': '/accounts/auth_requests/bb7a881c-9c34-11e9-9152-0028f8484bd5/authenticate/ui/',
        'uuid': 'bb7a881c-9c34-11e9-9152-0028f8484bd5',
    })
)
response
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-0b5df92b2387> in <module>
#       4         'Authorization': f'Bearer {AUTH_TOKEN}'
#       5     },
# ----> 6     data=json.dumps({
#       7         'account': '/accounts/auth_requests/bb7a881c-9c34-11e9-9152-0028f8484bd5/authenticate/ui/',
#       8         'uuid': 'bb7a881c-9c34-11e9-9152-0028f8484bd5',
#
# NameError: name 'json' is not defined

# %%
response.json()
# Out:
# {'@type': 'error', '@event': 'AUTH_TOKEN_MISSING_ACCOUNT'}

# %% [markdown]
# # BULK_READ_DOWNLOADREQUESTS

# %%
response = requests.get(
    'http://127.0.0.1:8887/downloader/requests/',
     headers={
        'Authorization': f'Bearer {AUTH_TOKEN}'
    },
)
response.json()
# Out:
# {'requests': [{'id': 17,
#    'spec': {'columns': ['A'],
#     'filters': [{'name': 'A', 'value': 0, 'operator': '>'}],
#     'randomize_ratio': 0.9},
#    'uri': None,
#    'real_size': None,
#    'estimated_size': None,
#    'executor_job_id': None,
#    'catalogue_item': {'id': 10,
#     'name': '2_column',
#     'spec': [{'name': 'A',
#       'size': 8000080,
#       'type': 'INTEGER',
#       'is_enum': False,
#       'is_nullable': False,
#       'distribution': [{'count': 40, 'value_max': 21, 'value_min': 1},
#        {'count': 1546, 'value_max': 41, 'value_min': 21},
#        {'count': 23928, 'value_max': 61, 'value_min': 41},
#        {'count': 144995, 'value_max': 81, 'value_min': 61},
#        {'count': 348443, 'value_max': 101, 'value_min': 81},
#        {'count': 333839, 'value_max': 121, 'value_min': 101},
#        {'count': 126904, 'value_max': 141, 'value_min': 121},
#        {'count': 19179, 'value_max': 161, 'value_min': 141},
#        {'count': 1101, 'value_max': 181, 'value_min': 161},
#        {'count': 25, 'value_max': 201, 'value_min': 181}]},
#      {'name': 'B',
#       'size': 8000080,
#       'type': 'INTEGER',
#       'is_enum': False,
#       'is_nullable': False,
#       'distribution': [{'count': 21, 'value_max': 118, 'value_min': 97},
#        {'count': 1120, 'value_max': 139, 'value_min': 118},
#        {'count': 21361, 'value_max': 160, 'value_min': 139},
#        {'count': 148854, 'value_max': 181, 'value_min': 160},
#        {'count': 368067, 'value_max': 202, 'value_min': 181},
#        {'count': 334972, 'value_max': 223, 'value_min': 202},
#        {'count': 111566, 'value_max': 244, 'value_min': 223},
#        {'count': 13464, 'value_max': 265, 'value_min': 244},
#        {'count': 560, 'value_max': 286, 'value_min': 265},
#        {'count': 15, 'value_max': 307, 'value_min': 286}]}],
#     'sample': [],
#     'executor_type': 'LOCAL',
#     'created_by': None,
#     'updated_by': None,
#     'maintained_by': None,
#     '@type': 'catalogue_item'},
#    'created_by': {'id': 3,
#     'email': 'johnny@where.com',
#     'type': 'ADMIN',
#     '@type': 'account'},
#    'is_cancelled': False,
#    'chunks': [{'created_datetime': '2019-08-28T11:24:23.083410Z',
#      'updated_datetime': '2019-08-28T11:24:23.083549Z',
#      'catalogue_item': 10,
#      'data_path': '/home/maciej/projects/lakey/lakey-service/lakey_service/chunk/management/commands/partional_data/2_column/0.parquet',
#      '@type': 'chunk'},
#     {'created_datetime': '2019-08-28T11:24:23.083865Z',
#      'updated_datetime': '2019-08-28T11:24:23.083934Z',
#      'catalogue_item': 10,
#      'data_path': '/home/maciej/projects/lakey/lakey-service/lakey_service/chunk/management/commands/partional_data/2_column/1.parquet',
#      '@type': 'chunk'},
#     {'created_datetime': '2019-08-28T11:24:23.084171Z',
#      'updated_datetime': '2019-08-28T11:24:23.084223Z',
#      'catalogue_item': 10,
#      'data_path': '/home/maciej/projects/lakey/lakey-service/lakey_service/chunk/management/commands/partional_data/2_column/2.parquet',
#      '@type': 'chunk'},
#     {'created_datetime': '2019-08-28T11:24:23.084350Z',
#      'updated_datetime': '2019-08-28T11:24:23.084408Z',
#      'catalogue_item': 10,
#      'data_path': '/home/maciej/projects/lakey/lakey-service/lakey_service/chunk/management/commands/partional_data/2_column/3.parquet',
#      '@type': 'chunk'},
#     {'created_datetime': '2019-08-28T11:24:23.084561Z',
#      'updated_datetime': '2019-08-28T11:24:23.084617Z',
#      'catalogue_item': 10,
#      'data_path': '/home/maciej/projects/lakey/lakey-service/lakey_service/chunk/management/commands/partional_data/2_column/4.parquet',
#      '@type': 'chunk'},
#     {'created_datetime': '2019-08-28T11:24:23.084791Z',
#      'updated_datetime': '2019-08-28T11:24:23.084853Z',
#      'catalogue_item': 10,
#      'data_path': '/home/maciej/projects/lakey/lakey-service/lakey_service/chunk/management/commands/partional_data/2_column/5.parquet',
#      '@type': 'chunk'},
#     {'created_datetime': '2019-08-28T11:24:23.085043Z',
#      'updated_datetime': '2019-08-28T11:24:23.085109Z',
#      'catalogue_item': 10,
#      'data_path': '/home/maciej/projects/lakey/lakey-service/lakey_service/chunk/management/commands/partional_data/2_column/6.parquet',
#      '@type': 'chunk'},
#     {'created_datetime': '2019-08-28T11:24:23.085295Z',
#      'updated_datetime': '2019-08-28T11:24:23.085361Z',
#      'catalogue_item': 10,
#      'data_path': '/home/maciej/projects/lakey/lakey-service/lakey_service/chunk/management/commands/partional_data/2_column/7.parquet',
#      '@type': 'chunk'}],
#    '@type': 'download_request'}],
#  '@type': 'download_requests_list',
#  '@event': 'DOWNLOADREQUESTS_BULK_READ'}

# %% [markdown]
# # READ_OR_CREATE_DOWNLOADREQUEST

# %%
import json

# %%
response = requests.post(
    'http://127.0.0.1:8887/downloader/requests/',
     headers={
        'Authorization': f'Bearer {AUTH_TOKEN}'
    },
    data=json.dumps(
        {
            "spec": {
                "columns": [
                    "A",
                ],
                "filters": [
                    {
                        "name": "A",
                        "operator": ">",
                        "value": 0
                    },
                ],
                "randomize_ratio": 0.9
            },
            "catalogue_item_name": '2_column'
        },
    )
)
response.json()
# Out:
# {'id': 17,
#  'spec': {'columns': ['A'],
#   'filters': [{'name': 'A', 'value': 0, 'operator': '>'}],
#   'randomize_ratio': 0.9},
#  'uri': None,
#  'real_size': None,
#  'estimated_size': None,
#  'executor_job_id': None,
#  'catalogue_item': {'id': 10,
#   'name': '2_column',
#   'spec': [{'name': 'A',
#     'size': 8000080,
#     'type': 'INTEGER',
#     'is_enum': False,
#     'is_nullable': False,
#     'distribution': [{'count': 40, 'value_max': 21, 'value_min': 1},
#      {'count': 1546, 'value_max': 41, 'value_min': 21},
#      {'count': 23928, 'value_max': 61, 'value_min': 41},
#      {'count': 144995, 'value_max': 81, 'value_min': 61},
#      {'count': 348443, 'value_max': 101, 'value_min': 81},
#      {'count': 333839, 'value_max': 121, 'value_min': 101},
#      {'count': 126904, 'value_max': 141, 'value_min': 121},
#      {'count': 19179, 'value_max': 161, 'value_min': 141},
#      {'count': 1101, 'value_max': 181, 'value_min': 161},
#      {'count': 25, 'value_max': 201, 'value_min': 181}]},
#    {'name': 'B',
#     'size': 8000080,
#     'type': 'INTEGER',
#     'is_enum': False,
#     'is_nullable': False,
#     'distribution': [{'count': 21, 'value_max': 118, 'value_min': 97},
#      {'count': 1120, 'value_max': 139, 'value_min': 118},
#      {'count': 21361, 'value_max': 160, 'value_min': 139},
#      {'count': 148854, 'value_max': 181, 'value_min': 160},
#      {'count': 368067, 'value_max': 202, 'value_min': 181},
#      {'count': 334972, 'value_max': 223, 'value_min': 202},
#      {'count': 111566, 'value_max': 244, 'value_min': 223},
#      {'count': 13464, 'value_max': 265, 'value_min': 244},
#      {'count': 560, 'value_max': 286, 'value_min': 265},
#      {'count': 15, 'value_max': 307, 'value_min': 286}]}],
#   'sample': [],
#   'executor_type': 'LOCAL',
#   'created_by': None,
#   'updated_by': None,
#   'maintained_by': None,
#   '@type': 'catalogue_item'},
#  'created_by': {'id': 3,
#   'email': 'johnny@where.com',
#   'type': 'ADMIN',
#   '@type': 'account'},
#  'is_cancelled': True,
#  'chunks': [{'created_datetime': '2019-08-28T11:24:23.083410Z',
#    'updated_datetime': '2019-08-28T11:24:23.083549Z',
#    'catalogue_item': 10,
#    'data_path': '/home/maciej/projects/lakey/lakey-service/lakey_service/chunk/management/commands/partional_data/2_column/0.parquet',
#    'borders': [{'type': 'INTEGER',
#      'column': 'A',
#      'maximum': 86,
#      'minimum': 1,
#      'distribution': [{'count': 3, 'value_max': 9, 'value_min': 1},
#       {'count': 7, 'value_max': 18, 'value_min': 9},
#       {'count': 59, 'value_max': 26, 'value_min': 18},
#       {'count': 222, 'value_max': 35, 'value_min': 26},
#       {'count': 987, 'value_max': 43, 'value_min': 35},
#       {'count': 2822, 'value_max': 52, 'value_min': 43},
#       {'count': 8669, 'value_max': 60, 'value_min': 52},
#       {'count': 17487, 'value_max': 69, 'value_min': 60},
#       {'count': 37391, 'value_max': 77, 'value_min': 69},
#       {'count': 57353, 'value_max': 86, 'value_min': 77}]},
#     {'type': 'INTEGER',
#      'column': 'B',
#      'maximum': 200,
#      'minimum': 113,
#      'distribution': [{'count': 11, 'value_max': 121, 'value_min': 113},
#       {'count': 65, 'value_max': 130, 'value_min': 121},
#       {'count': 298, 'value_max': 139, 'value_min': 130},
#       {'count': 778, 'value_max': 147, 'value_min': 139},
#       {'count': 2805, 'value_max': 156, 'value_min': 147},
#       {'count': 7509, 'value_max': 165, 'value_min': 156},
#       {'count': 13288, 'value_max': 173, 'value_min': 165},
#       {'count': 24758, 'value_max': 182, 'value_min': 173},
#       {'count': 35631, 'value_max': 191, 'value_min': 182},
#       {'count': 39857, 'value_max': 200, 'value_min': 191}]}],
#    '@type': 'chunk'},
#   {'created_datetime': '2019-08-28T11:24:23.083865Z',
#    'updated_datetime': '2019-08-28T11:24:23.083934Z',
#    'catalogue_item': 10,
#    'data_path': '/home/maciej/projects/lakey/lakey-service/lakey_service/chunk/management/commands/partional_data/2_column/1.parquet',
#    'borders': [{'type': 'INTEGER',
#      'column': 'A',
#      'maximum': 100,
#      'minimum': 86,
#      'distribution': [{'count': 12442, 'value_max': 87, 'value_min': 86},
#       {'count': 8412, 'value_max': 88, 'value_min': 87},
#       {'count': 17455, 'value_max': 90, 'value_min': 88},
#       {'count': 9085, 'value_max': 91, 'value_min': 90},
#       {'count': 9263, 'value_max': 93, 'value_min': 91},
#       {'count': 19061, 'value_max': 94, 'value_min': 93},
#       {'count': 9711, 'value_max': 95, 'value_min': 94},
#       {'count': 19618, 'value_max': 97, 'value_min': 95},
#       {'count': 9734, 'value_max': 98, 'value_min': 97},
#       {'count': 10219, 'value_max': 100, 'value_min': 98}]},
#     {'type': 'INTEGER',
#      'column': 'B',
#      'maximum': 200,
#      'minimum': 97,
#      'distribution': [{'count': 2, 'value_max': 107, 'value_min': 97},
#       {'count': 2, 'value_max': 117, 'value_min': 107},
#       {'count': 41, 'value_max': 127, 'value_min': 117},
#       {'count': 239, 'value_max': 138, 'value_min': 127},
#       {'count': 978, 'value_max': 148, 'value_min': 138},
#       {'count': 3496, 'value_max': 158, 'value_min': 148},
#       {'count': 11541, 'value_max': 169, 'value_min': 158},
#       {'count': 23255, 'value_max': 179, 'value_min': 169},
#       {'count': 38413, 'value_max': 189, 'value_min': 179},
#       {'count': 47033, 'value_max': 200, 'value_min': 189}]}],
#    '@type': 'chunk'},
#   {'created_datetime': '2019-08-28T11:24:23.084171Z',
#    'updated_datetime': '2019-08-28T11:24:23.084223Z',
#    'catalogue_item': 10,
#    'data_path': '/home/maciej/projects/lakey/lakey-service/lakey_service/chunk/management/commands/partional_data/2_column/2.parquet',
#    'borders': [{'type': 'INTEGER',
#      'column': 'A',
#      'maximum': 113,
#      'minimum': 100,
#      'distribution': [{'count': 19670, 'value_max': 101, 'value_min': 100},
#       {'count': 9863, 'value_max': 102, 'value_min': 101},
#       {'count': 9811, 'value_max': 103, 'value_min': 102},
#       {'count': 19215, 'value_max': 105, 'value_min': 103},
#       {'count': 9521, 'value_max': 106, 'value_min': 105},
#       {'count': 9236, 'value_max': 107, 'value_min': 106},
#       {'count': 17888, 'value_max': 109, 'value_min': 107},
#       {'count': 8705, 'value_max': 110, 'value_min': 109},
#       {'count': 8474, 'value_max': 111, 'value_min': 110},
#       {'count': 12617, 'value_max': 113, 'value_min': 111}]},
#     {'type': 'INTEGER',
#      'column': 'B',
#      'maximum': 200,
#      'minimum': 107,
#      'distribution': [{'count': 7, 'value_max': 116, 'value_min': 107},
#       {'count': 24, 'value_max': 125, 'value_min': 116},
#       {'count': 120, 'value_max': 134, 'value_min': 125},
#       {'count': 618, 'value_max': 144, 'value_min': 134},
#       {'count': 1895, 'value_max': 153, 'value_min': 144},
#       {'count': 5330, 'value_max': 162, 'value_min': 153},
#       {'count': 13955, 'value_max': 172, 'value_min': 162},
#       {'count': 23986, 'value_max': 181, 'value_min': 172},
#       {'count': 35817, 'value_max': 190, 'value_min': 181},
#       {'count': 43248, 'value_max': 200, 'value_min': 190}]}],
#    '@type': 'chunk'},
#   {'created_datetime': '2019-08-28T11:24:23.084350Z',
#    'updated_datetime': '2019-08-28T11:24:23.084408Z',
#    'catalogue_item': 10,
#    'data_path': '/home/maciej/projects/lakey/lakey-service/lakey_service/chunk/management/commands/partional_data/2_column/3.parquet',
#    'borders': [{'type': 'INTEGER',
#      'column': 'A',
#      'maximum': 189,
#      'minimum': 113,
#      'distribution': [{'count': 51212, 'value_max': 120, 'value_min': 113},
#       {'count': 36744, 'value_max': 128, 'value_min': 120},
#       {'count': 18925, 'value_max': 135, 'value_min': 128},
#       {'count': 11017, 'value_max': 143, 'value_min': 135},
#       {'count': 4359, 'value_max': 151, 'value_min': 143},
#       {'count': 1979, 'value_max': 158, 'value_min': 151},
#       {'count': 556, 'value_max': 166, 'value_min': 158},
#       {'count': 164, 'value_max': 173, 'value_min': 166},
#       {'count': 35, 'value_max': 181, 'value_min': 173},
#       {'count': 9, 'value_max': 189, 'value_min': 181}]},
#     {'type': 'INTEGER',
#      'column': 'B',
#      'maximum': 200,
#      'minimum': 113,
#      'distribution': [{'count': 14, 'value_max': 121, 'value_min': 113},
#       {'count': 55, 'value_max': 130, 'value_min': 121},
#       {'count': 248, 'value_max': 139, 'value_min': 130},
#       {'count': 814, 'value_max': 147, 'value_min': 139},
#       {'count': 2785, 'value_max': 156, 'value_min': 147},
#       {'count': 7116, 'value_max': 165, 'value_min': 156},
#       {'count': 13118, 'value_max': 173, 'value_min': 165},
#       {'count': 25316, 'value_max': 182, 'value_min': 173},
#       {'count': 36506, 'value_max': 191, 'value_min': 182},
#       {'count': 39028, 'value_max': 200, 'value_min': 191}]}],
#    '@type': 'chunk'},
#   {'created_datetime': '2019-08-28T11:24:23.084561Z',
#    'updated_datetime': '2019-08-28T11:24:23.084617Z',
#    'catalogue_item': 10,
#    'data_path': '/home/maciej/projects/lakey/lakey-service/lakey_service/chunk/management/commands/partional_data/2_column/4.parquet',
#    'borders': [{'type': 'INTEGER',
#      'column': 'A',
#      'maximum': 100,
#      'minimum': 5,
#      'distribution': [{'count': 3, 'value_max': 14, 'value_min': 5},
#       {'count': 10, 'value_max': 24, 'value_min': 14},
#       {'count': 103, 'value_max': 33, 'value_min': 24},
#       {'count': 436, 'value_max': 43, 'value_min': 33},
#       {'count': 1704, 'value_max': 52, 'value_min': 43},
#       {'count': 4964, 'value_max': 62, 'value_min': 52},
#       {'count': 12578, 'value_max': 71, 'value_min': 62},
#       {'count': 22776, 'value_max': 81, 'value_min': 71},
#       {'count': 38892, 'value_max': 90, 'value_min': 81},
#       {'count': 43534, 'value_max': 100, 'value_min': 90}]},
#     {'type': 'INTEGER',
#      'column': 'B',
#      'maximum': 213,
#      'minimum': 200,
#      'distribution': [{'count': 19707, 'value_max': 201, 'value_min': 200},
#       {'count': 9883, 'value_max': 202, 'value_min': 201},
#       {'count': 9789, 'value_max': 203, 'value_min': 202},
#       {'count': 19278, 'value_max': 205, 'value_min': 203},
#       {'count': 9580, 'value_max': 206, 'value_min': 205},
#       {'count': 9425, 'value_max': 207, 'value_min': 206},
#       {'count': 18325, 'value_max': 209, 'value_min': 207},
#       {'count': 8677, 'value_max': 210, 'value_min': 209},
#       {'count': 8445, 'value_max': 211, 'value_min': 210},
#       {'count': 11891, 'value_max': 213, 'value_min': 211}]}],
#    '@type': 'chunk'},
#   {'created_datetime': '2019-08-28T11:24:23.084791Z',
#    'updated_datetime': '2019-08-28T11:24:23.084853Z',
#    'catalogue_item': 10,
#    'data_path': '/home/maciej/projects/lakey/lakey-service/lakey_service/chunk/management/commands/partional_data/2_column/5.parquet',
#    'borders': [{'type': 'INTEGER',
#      'column': 'A',
#      'maximum': 100,
#      'minimum': 10,
#      'distribution': [{'count': 3, 'value_max': 19, 'value_min': 10},
#       {'count': 44, 'value_max': 28, 'value_min': 19},
#       {'count': 164, 'value_max': 37, 'value_min': 28},
#       {'count': 702, 'value_max': 46, 'value_min': 37},
#       {'count': 2245, 'value_max': 55, 'value_min': 46},
#       {'count': 5697, 'value_max': 64, 'value_min': 55},
#       {'count': 13380, 'value_max': 73, 'value_min': 64},
#       {'count': 23585, 'value_max': 82, 'value_min': 73},
#       {'count': 35195, 'value_max': 91, 'value_min': 82},
#       {'count': 43985, 'value_max': 100, 'value_min': 91}]},
#     {'type': 'INTEGER',
#      'column': 'B',
#      'maximum': 293,
#      'minimum': 213,
#      'distribution': [{'count': 51440, 'value_max': 221, 'value_min': 213},
#       {'count': 36719, 'value_max': 229, 'value_min': 221},
#       {'count': 20581, 'value_max': 237, 'value_min': 229},
#       {'count': 10068, 'value_max': 245, 'value_min': 237},
#       {'count': 4126, 'value_max': 253, 'value_min': 245},
#       {'count': 1506, 'value_max': 261, 'value_min': 253},
#       {'count': 417, 'value_max': 269, 'value_min': 261},
#       {'count': 114, 'value_max': 277, 'value_min': 269},
#       {'count': 22, 'value_max': 285, 'value_min': 277},
#       {'count': 7, 'value_max': 293, 'value_min': 285}]}],
#    '@type': 'chunk'},
#   {'created_datetime': '2019-08-28T11:24:23.085043Z',
#    'updated_datetime': '2019-08-28T11:24:23.085109Z',
#    'catalogue_item': 10,
#    'data_path': '/home/maciej/projects/lakey/lakey-service/lakey_service/chunk/management/commands/partional_data/2_column/6.parquet',
#    'borders': [{'type': 'INTEGER',
#      'column': 'A',
#      'maximum': 201,
#      'minimum': 100,
#      'distribution': [{'count': 52067, 'value_max': 110, 'value_min': 100},
#       {'count': 36071, 'value_max': 120, 'value_min': 110},
#       {'count': 21656, 'value_max': 130, 'value_min': 120},
#       {'count': 10271, 'value_max': 140, 'value_min': 130},
#       {'count': 3622, 'value_max': 150, 'value_min': 140},
#       {'count': 1032, 'value_max': 160, 'value_min': 150},
#       {'count': 237, 'value_max': 170, 'value_min': 160},
#       {'count': 36, 'value_max': 180, 'value_min': 170},
#       {'count': 6, 'value_max': 190, 'value_min': 180},
#       {'count': 2, 'value_max': 201, 'value_min': 190}]},
#     {'type': 'INTEGER',
#      'column': 'B',
#      'maximum': 213,
#      'minimum': 200,
#      'distribution': [{'count': 19716, 'value_max': 201, 'value_min': 200},
#       {'count': 9787, 'value_max': 202, 'value_min': 201},
#       {'count': 9936, 'value_max': 203, 'value_min': 202},
#       {'count': 19551, 'value_max': 205, 'value_min': 203},
#       {'count': 9487, 'value_max': 206, 'value_min': 205},
#       {'count': 9202, 'value_max': 207, 'value_min': 206},
#       {'count': 18109, 'value_max': 209, 'value_min': 207},
#       {'count': 8614, 'value_max': 210, 'value_min': 209},
#       {'count': 8413, 'value_max': 211, 'value_min': 210},
#       {'count': 12185, 'value_max': 213, 'value_min': 211}]}],
#    '@type': 'chunk'},
#   {'created_datetime': '2019-08-28T11:24:23.085295Z',
#    'updated_datetime': '2019-08-28T11:24:23.085361Z',
#    'catalogue_item': 10,
#    'data_path': '/home/maciej/projects/lakey/lakey-service/lakey_service/chunk/management/commands/partional_data/2_column/7.parquet',
#    'borders': [{'type': 'INTEGER',
#      'column': 'A',
#      'maximum': 191,
#      'minimum': 100,
#      'distribution': [{'count': 47832, 'value_max': 109, 'value_min': 100},
#       {'count': 34475, 'value_max': 118, 'value_min': 109},
#       {'count': 22620, 'value_max': 127, 'value_min': 118},
#       {'count': 11959, 'value_max': 136, 'value_min': 127},
#       {'count': 5401, 'value_max': 145, 'value_min': 136},
#       {'count': 1934, 'value_max': 154, 'value_min': 145},
#       {'count': 595, 'value_max': 163, 'value_min': 154},
#       {'count': 138, 'value_max': 172, 'value_min': 163},
#       {'count': 39, 'value_max': 181, 'value_min': 172},
#       {'count': 7, 'value_max': 191, 'value_min': 181}]},
#     {'type': 'INTEGER',
#      'column': 'B',
#      'maximum': 307,
#      'minimum': 213,
#      'distribution': [{'count': 62185, 'value_max': 222, 'value_min': 213},
#       {'count': 35081, 'value_max': 231, 'value_min': 222},
#       {'count': 18710, 'value_max': 241, 'value_min': 231},
#       {'count': 6409, 'value_max': 250, 'value_min': 241},
#       {'count': 1964, 'value_max': 260, 'value_min': 250},
#       {'count': 553, 'value_max': 269, 'value_min': 260},
#       {'count': 81, 'value_max': 278, 'value_min': 269},
#       {'count': 12, 'value_max': 288, 'value_min': 278},
#       {'count': 4, 'value_max': 297, 'value_min': 288},
#       {'count': 1, 'value_max': 307, 'value_min': 297}]}],
#    '@type': 'chunk'}],
#  '@type': 'download_request',
#  '@event': 'DOWNLOADREQUEST_READ'}

# %% [markdown]
# # DELETE_DOWNLOADREQUEST

# %%
response = requests.delete(
    'http://127.0.0.1:8887/downloader/requests/17',
     headers={
        'Authorization': f'Bearer {AUTH_TOKEN}'
    }
)
response
# Out:
# <Response [200]>

# %%
borders = [[] for _ in range(5)]
borders[0].append(0)
borders
# Out:
# [[0], [], [], [], []]

# %% [markdown]
# # ESTIMATE_SIZE_OF_DOWNLOAD_REQUEST

# %%
response = requests.post(
    'http://127.0.0.1:8887/downloader/requests/estimate/',
    headers={
        'Authorization': f'Bearer {AUTH_TOKEN}'
    },
    json={
        'spec': {
            'columns': ['A'],
            'filters': [
                {
                    'name': 'A',
                    'operator': '>=',
                    'value': 100,
                },
   
            ],
            'randomize_ratio': 1,
        },
        "catalogue_item_name": '2_column'
    }
)
response.json()
# Out:
# {'estimated_size': 14000140,
#  '@type': 'download_request_estimated_size',
#  '@event': 'SIZE_OF_DOWNLOAD_REQUEST_ESTIMATED'}
