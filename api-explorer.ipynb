# %%
import requests

# %% [markdown]
# # ENTRYPOINT

# %%
response = requests.get('http://127.0.0.1:8887')

commands = response.json()['commands']

# %%
sorted(commands.keys())
# Out:
# ['ATTACH_ACCOUNT_TO_AUTH_REQUEST',
#  'BULK_READ_CATALOGUEITEMS',
#  'BULK_READ_DOWNLOADREQUESTS',
#  'CREATE_AUTH_REQUEST',
#  'CREATE_AUTH_TOKEN',
#  'CREATE_CATALOGUEITEM',
#  'DELETE_CATALOGUEITEM',
#  'DELETE_DOWNLOADREQUEST',
#  'ESTIMATE_SIZE_OF_DOWNLOAD_REQUEST',
#  'READ_CATALOGUEITEM',
#  'READ_DOWNLOADREQUEST',
#  'READ_ENTRY_POINT',
#  'READ_OR_CREATE_DOWNLOADREQUEST',
#  'RENDER_AUTH_REQUEST_AUTHENTICATE_UI',
#  'RENDER_DOWNLOAD_REQUEST_UI_DATA',
#  'UPDATE_CATALOGUEITEM',
#  'WITH_SAMPLE_AND_DISTRIBUTION_UPDATE_CATALOGUEITEM']

# %%
commands['CREATE_CATALOGUEITEM']
# Out:
# {'method': 'post',
#  'path_conf': {'path': '/catalogue/items/', 'parameters': []},
#  'meta': {'title': 'Create Catalogue Item',
#   'description': None,
#   'domain': {'id': 'catalogue',
#    'name': 'Catalogue Items Management',
#    '@type': 'domain'},
#   '@type': 'meta'},
#  'access': {'access_list': ['ADMIN'],
#   'is_private': False,
#   'is_external': False,
#   '@type': 'access'},
#  'source': {'filepath': '/lakey_service/catalogue/commands.py',
#   'start_line': 25,
#   'end_line': 44,
#   '@type': 'source'},
#  'schemas': {'output': {'uri': 'https://github.com/cosphere-org/lakey-service/blob/435ffe64f5c4ba0da60a6b829b5178de3a22b993/lakey_service/catalogue/serializers.py/#L8',
#    'schema': {'type': 'object',
#     'required': ['name',
#      'spec',
#      'executor_type',
#      'created_by',
#      'updated_by',
#      'maintained_by'],
#     'properties': {'id': {'type': 'integer'},
#      'name': {'type': 'string', 'maxLength': 256},
#      'spec': {'type': 'array',
#       'items': {'type': 'object',
#        'properties': {'name': {'type': 'string'},
#         'description': {'type': 'string'},
#         'type': {'type': 'string',
#          'enum_name': None,
#          'enum': ['INTEGER', 'FLOAT', 'STRING', 'BOOLEAN', 'DATETIME']},
#         'is_enum': {'type': 'boolean'},
#         'size': {'oneOf': [{'type': 'null'}, {'type': 'number'}]},
#         'is_nullable': {'type': 'boolean'},
#         'distribution': {'oneOf': [{'type': 'null'},
#           {'type': 'array',
#            'items': {'type': 'object',
#             'properties': {'value': {'oneOf': [{'type': 'null'},
#                {'type': 'number'},
#                {'type': 'string'},
#                {'type': 'boolean'}]},
#              'count': {'type': 'number'}},
#             'required': ['value', 'count']}}]}},
#        'required': ['name',
#         'type',
#         'size',
#         'is_nullable',
#         'distribution',
#         'is_enum']}},
#      'sample': {'type': 'array',
#       'items': {'type': 'object', 'properties': {}}},
#      'executor_type': {'type': 'string',
#       'enum_name': 'Executor',
#       'enum': ['ATHENA', 'DATABRICKS']},
#      'created_by': {'type': 'object',
#       'required': ['email'],
#       'properties': {'id': {'type': 'integer'},
#        'email': {'type': 'string', 'format': 'email'},
#        'type': {'type': 'string',
#         'enum_name': 'account_type',
#         'enum': ['ADMIN', 'RESEARCHER']}}},
#      'updated_by': {'type': 'object',
#       'required': ['email'],
#       'properties': {'id': {'type': 'integer'},
#        'email': {'type': 'string', 'format': 'email'},
#        'type': {'type': 'string',
#         'enum_name': 'account_type',
#         'enum': ['ADMIN', 'RESEARCHER']}}},
#      'maintained_by': {'type': 'object',
#       'required': ['email'],
#       'properties': {'id': {'type': 'integer'},
#        'email': {'type': 'string', 'format': 'email'},
#        'type': {'type': 'string',
#         'enum_name': 'account_type',
#         'enum': ['ADMIN', 'RESEARCHER']}}}}}},
#   'input_body': {'uri': 'https://github.com/cosphere-org/lakey-service/blob/435ffe64f5c4ba0da60a6b829b5178de3a22b993/lakey_service/catalogue/parsers.py/#L7',
#    'schema': {'type': 'object',
#     'required': ['name', 'spec', 'maintained_by_id', 'executor_type'],
#     'properties': {'name': {'type': 'string', 'maxLength': 256},
#      'spec': {'type': 'array',
#       'items': {'type': 'object',
#        'properties': {'name': {'type': 'string'},
#         'description': {'type': 'string'},
#         'type': {'type': 'string',
#          'enum_name': None,
#          'enum': ['INTEGER', 'FLOAT', 'STRING', 'BOOLEAN', 'DATETIME']},
#         'is_enum': {'type': 'boolean'},
#         'size': {'oneOf': [{'type': 'null'}, {'type': 'number'}]},
#         'is_nullable': {'type': 'boolean'},
#         'distribution': {'oneOf': [{'type': 'null'},
#           {'type': 'array',
#            'items': {'type': 'object',
#             'properties': {'value': {'oneOf': [{'type': 'null'},
#                {'type': 'number'},
#                {'type': 'string'},
#                {'type': 'boolean'}]},
#              'count': {'type': 'number'}},
#             'required': ['value', 'count']}}]}},
#        'required': ['name',
#         'type',
#         'size',
#         'is_nullable',
#         'distribution',
#         'is_enum']}},
#      'sample': {'type': 'array',
#       'items': {'type': 'object', 'properties': {}}},
#      'maintained_by_id': {'type': 'integer'},
#      'executor_type': {'type': 'string',
#       'enum_name': 'Executor',
#       'enum': ['ATHENA', 'DATABRICKS']}}}}},
#  'examples': {'400 (BODY_JSON_DID_NOT_PARSE)': {'method': 'post',
#    'description': 'BODY_JSON_DID_NOT_PARSE',
#    'request': {'path': '/catalogue/items/',
#     'content': {'name': 'iot_events',
#      'sample': [],
#      'spec': [{'name': 'value',
#        'type': 'FLOAT',
#        'size': 19203,
#        'is_nullable': False,
#        'is_enum': False,
#        'distribution': None}],
#      'maintained_by_id': 932039,
#      'executor_type': 'DATABRICKS'},
#     'headers': {'CONTENT-TYPE': 'application/json',
#      'AUTHORIZATION': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpZCI6NjcsImVtYWlsIjoiZG9uaXRhY3Jpc3RAbWVydHouY29tIiwidHlwZSI6IkFETUlOIiwiZXhwIjoxNTYyMDk0OTkxfQ.dRvpyMLbmA5IAYyYzaDLW1nV-kroaFMHl5ron0YUeRs'},
#     'parameters': {}},
#    'response': {'status': 400,
#     'content_type': 'application/json',
#     'content': {'errors': {'maintained_by': ['account instance with id 932039 does not exist.']},
#      '@type': 'error',
#      '@event': 'BODY_JSON_DID_NOT_PARSE',
#      '@access': {'account_id': 67}}}},
#   '201 (CATALOGUEITEM_CREATED)': {'method': 'post',
#    'description': 'CATALOGUEITEM_CREATED',
#    'request': {'path': '/catalogue/items/',
#     'content': {'name': 'iot_events',
#      'sample': [],
#      'spec': [{'name': 'value',
#        'type': 'FLOAT',
#        'size': 19203,
#        'is_nullable': False,
#        'is_enum': False,
#        'distribution': None}],
#      'maintained_by_id': 72,
#      'executor_type': 'DATABRICKS'},
#     'headers': {'CONTENT-TYPE': 'application/json',
#      'AUTHORIZATION': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpZCI6NzEsImVtYWlsIjoiZG9uaXRhY3Jpc3RAbWVydHouY29tIiwidHlwZSI6IkFETUlOIiwiZXhwIjoxNTYyMDk0OTkxfQ.UUTgIqu4oB_6w_jIVKsmsBKRrxxoSXiDkqCA1QunVtw'},
#     'parameters': {}},
#    'response': {'status': 201,
#     'content_type': 'application/json',
#     'content': {'id': 61,
#      'name': 'iot_events',
#      'spec': [{'name': 'value',
#        'type': 'FLOAT',
#        'size': 19203,
#        'is_nullable': False,
#        'is_enum': False,
#        'distribution': None}],
#      'sample': [],
#      'executor_type': 'DATABRICKS',
#      'created_by': {'id': 71,
#       'email': 'donitacrist@mertz.com',
#       'type': 'ADMIN',
#       '@type': 'account'},
#      'updated_by': {'id': 71,
#       'email': 'donitacrist@mertz.com',
#       'type': 'ADMIN',
#       '@type': 'account'},
#      'maintained_by': {'id': 72,
#       'email': 'rabernathy@gerhold.info',
#       'type': 'RESEARCHER',
#       '@type': 'account'},
#      '@type': 'catalogue_item',
#      '@event': 'CATALOGUEITEM_CREATED'}}},
#   '400 (BODY_DID_NOT_VALIDATE)': {'method': 'post',
#    'description': 'BODY_DID_NOT_VALIDATE',
#    'request': {'path': '/catalogue/items/',
#     'content': {'name': 'iot_events',
#      'sample': [],
#      'spec': [{'name': 'value',
#        'size': 19203,
#        'is_nullable': False,
#        'distribution': None}],
#      'maintained_by_id': 77,
#      'executor_type': 'DATABRICKS'},
#     'headers': {'CONTENT-TYPE': 'application/json',
#      'AUTHORIZATION': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpZCI6NzYsImVtYWlsIjoiZG9uaXRhY3Jpc3RAbWVydHouY29tIiwidHlwZSI6IkFETUlOIiwiZXhwIjoxNTYyMDk0OTkyfQ.XG9gsWM2CEA0moc4zgaYGr--PAktAwS64EkWYlz-eV8'},
#     'parameters': {}},
#    'response': {'status': 400,
#     'content_type': 'application/json',
#     'content': {'errors': {'spec': ["JSON did not validate. PATH: '0' REASON: 'type' is a required property"]},
#      '@type': 'error',
#      '@event': 'BODY_DID_NOT_VALIDATE',
#      '@access': {'account_id': 76}}}}},
#  '@type': 'command'}

# %% [markdown]
# ## Create Auth Token
#
# In the console:
#
# ```bash
# source env.sh && python lakey_service/manage.py create_account johnny@where.com --type ADMIN
# source env.sh && python lakey_service/manage.py create_auth_token johnny@where.com
# ```

# %%
AUTH_TOKEN = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpZCI6MywiZW1haWwiOiJqb2hubnlAd2hlcmUuY29tIiwidHlwZSI6IkFETUlOIiwiZXhwIjoxNTY1NDI4MjIyfQ.Fwtz7LVPb2dXHk2mHL0onrN2-uLQU48ZVrYvwO6ZrwY'

# %% [markdown]
# # BULK READ CATALOGUE ITEM

# %%
response = requests.get(
    'http://127.0.0.1:8887/catalogue/items/',
    headers={
        'Authorization': f'Bearer {AUTH_TOKEN}'
    })

response.json()
# Out:
# {'items': [{'id': 2,
#    'name': 'iot.features',
#    'spec': [{'name': 'gateway_uuid',
#      'size': None,
#      'type': 'STRING',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'timestamp',
#      'size': None,
#      'type': 'DATETIME',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'property',
#      'size': None,
#      'type': 'STRING',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'value',
#      'size': None,
#      'type': 'FLOAT',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'month',
#      'size': None,
#      'type': 'INTEGER',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'day',
#      'size': None,
#      'type': 'INTEGER',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None}],
#    'sample': [],
#    'executor_type': 'ATHENA',
#    'created_by': None,
#    'updated_by': None,
#    'maintained_by': None,
#    '@type': 'catalogue_item'},
#   {'id': 3,
#    'name': 'iot.devices',
#    'spec': [{'name': 'gateway_uuid',
#      'size': None,
#      'type': 'STRING',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'geo_lat',
#      'size': None,
#      'type': 'FLOAT',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'geo_lng',
#      'size': None,
#      'type': 'FLOAT',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'zip_code',
#      'size': None,
#      'type': 'STRING',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None}],
#    'sample': [],
#    'executor_type': 'ATHENA',
#    'created_by': None,
#    'updated_by': None,
#    'maintained_by': None,
#    '@type': 'catalogue_item'},
#   {'id': 4,
#    'name': 'external.weather',
#    'spec': [{'name': 'zip_code',
#      'size': None,
#      'type': 'STRING',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'obs_geo_lat',
#      'size': None,
#      'type': 'FLOAT',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'obs_geo_lng',
#      'size': None,
#      'type': 'FLOAT',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'obs_name',
#      'size': None,
#      'type': 'STRING',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'timestamp',
#      'size': None,
#      'type': 'DATETIME',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'temp',
#      'size': None,
#      'type': 'FLOAT',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None}],
#    'sample': [],
#    'executor_type': 'ATHENA',
#    'created_by': None,
#    'updated_by': None,
#    'maintained_by': None,
#    '@type': 'catalogue_item'},
#   {'id': 5,
#    'name': 'sap.sales',
#    'spec': [{'name': 'product',
#      'size': None,
#      'type': 'STRING',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'obs_geo_lat',
#      'size': None,
#      'type': 'FLOAT',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'client_id',
#      'size': None,
#      'type': 'INTEGER',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'sold_datetime',
#      'size': None,
#      'type': 'DATETIME',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None}],
#    'sample': [],
#    'executor_type': 'ATHENA',
#    'created_by': None,
#    'updated_by': None,
#    'maintained_by': None,
#    '@type': 'catalogue_item'},
#   {'id': 6,
#    'name': 'sap.client',
#    'spec': [{'name': 'name',
#      'size': None,
#      'type': 'STRING',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'client_id',
#      'size': None,
#      'type': 'INTEGER',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'sap_id',
#      'size': None,
#      'type': 'INTEGER',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None}],
#    'sample': [],
#    'executor_type': 'ATHENA',
#    'created_by': None,
#    'updated_by': None,
#    'maintained_by': None,
#    '@type': 'catalogue_item'},
#   {'id': 7,
#    'name': 'google_analytics.website_stats',
#    'spec': [{'name': 'url',
#      'size': None,
#      'type': 'STRING',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'click_element',
#      'size': None,
#      'type': 'STRING',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None},
#     {'name': 'click_datetime',
#      'size': None,
#      'type': 'DATETIME',
#      'is_enum': False,
#      'is_nullable': False,
#      'distribution': None}],
#    'sample': [],
#    'executor_type': 'ATHENA',
#    'created_by': None,
#    'updated_by': None,
#    'maintained_by': None,
#    '@type': 'catalogue_item'},
#   {'id': 8,
#    'name': 'iot operational data',
#    'spec': [{'name': 'property',
#      'size': 190234,
#      'type': 'STRING',
#      'is_enum': True,
#      'description': 'what event type are we dealing with',
#      'is_nullable': False,
#      'distribution': [{'count': 134, 'value': 'outside.temperature/value'},
#       {'count': 6789, 'value': 'inside.temperature/value'},
#       {'count': 567, 'value': 'super.pressure/value'},
#       {'count': 12, 'value': 'normal.pressure/value'},
#       {'count': 671, 'value': 'wifi.strength/value'},
#       {'count': 12, 'value': 'wifi.weakness/value'}]},
#     {'name': 'value',
#      'size': 67,
#      'type': 'FLOAT',
#      'is_enum': False,
#      'description': 'the value of a particular property',
#      'is_nullable': True,
#      'distribution': [{'count': 56, 'value': 1.0},
#       {'count': 567, 'value': 2.0},
#       {'count': 567, 'value': 4.0},
#       {'count': 1235, 'value': 34.0},
#       {'count': 8799, 'value': 45.0}]}],
#    'sample': [{'value': 1.2, 'property': 'wifi.strength/value'},
#     {'value': 48.1, 'property': 'normal.pressure/value'},
#     {'value': 56.6, 'property': 'inside.temperature/value'},
#     {'value': 345.1, 'property': 'inside.temperature/value'},
#     {'value': 1.21, 'property': 'inside.temperature/value'},
#     {'value': 19.1, 'property': 'normal.pressure/value'}],
#    'executor_type': 'DATABRICKS',
#    'created_by': None,
#    'updated_by': None,
#    'maintained_by': {'id': 1,
#     'email': 'maciej@cosphere.org',
#     'type': 'ADMIN',
#     '@type': 'account'},
#    '@type': 'catalogue_item'},
#   {'id': 9,
#    'name': 'sales data',
#    'spec': [{'name': 'client_id',
#      'size': 190234,
#      'type': 'STRING',
#      'is_enum': False,
#      'description': 'the unique identifier of the client',
#      'is_nullable': False,
#      'distribution': [{'count': 1342, 'value': 'jacky.1'},
#       {'count': 6789, 'value': 'johnny.12'},
#       {'count': 567, 'value': 'bobby.4'}]},
#     {'name': 'paid',
#      'size': 67,
#      'type': 'FLOAT',
#      'is_enum': False,
#      'description': 'amount of money paid',
#      'is_nullable': True,
#      'distribution': [{'count': 56, 'value': 1.0},
#       {'count': 567, 'value': 2.0},
#       {'count': 567, 'value': 4.0},
#       {'count': 1235, 'value': 34.0},
#       {'count': 8799, 'value': 45.0}]},
#     {'name': 'currency',
#      'size': 67,
#      'type': 'STRING',
#      'is_enum': False,
#      'description': 'currency in which payment occurred',
#      'is_nullable': True,
#      'distribution': [{'count': 563, 'value': 'EUR'},
#       {'count': 567, 'value': 'USD'},
#       {'count': 567, 'value': 'PLN'}]}],
#    'sample': [{'paid': 112.25, 'currency': 'EUR', 'client_id': 'jacky.2'},
#     {'paid': 4500.0, 'currency': 'PLN', 'client_id': 'alice.2'},
#     {'paid': 56.78, 'currency': 'USD', 'client_id': 'john.567'}],
#    'executor_type': 'DATABRICKS',
#    'created_by': None,
#    'updated_by': None,
#    'maintained_by': {'id': 1,
#     'email': 'maciej@cosphere.org',
#     'type': 'ADMIN',
#     '@type': 'account'},
#    '@type': 'catalogue_item'}],
#  '@type': 'catalogue_items_list',
#  '@event': 'CATALOGUEITEMS_BULK_READ'}

# %% [markdown]
# # CREATE CATALOGUE ITEM

# %%
# .. @pszp here!!!
